# %% [markdown]
# <a href="https://colab.research.google.com/github/safranco8/entregables-grupo-31/blob/main/AEyC/20220607_entregable_parte_1_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Exploración y Curación de Datos**
#
# *Edición 2022*
#
# ----
# # **Grupo 31**
# ## Integrantes:
#
# Victor Nicolas Rocco
#
# Maria Mercedes Silva
#
# Santiago Franco
#
# Williams Gremoliche
#
# # Trabajo práctico entregable - parte 1
#
#
# En esta notebook, vamos a cargar el conjunto de datos de [la compentencia Kaggle](https://www.kaggle.com/dansbecker/melbourne-housing-snapshot) sobre estimación de precios de ventas de propiedades en Melbourne, Australia.
#
# Utilizaremos el conjunto de datos reducido producido por [DanB](https://www.kaggle.com/dansbecker). Hemos subido una copia a un servidor de la Universidad Nacional de Córdoba para facilitar su acceso remoto.

# %%
#010 Instalamos librería necesaria 
# !pip install python-decouple
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-decouple
#   Downloading python_decouple-3.6-py3-none-any.whl (9.9 kB)
# Installing collected packages: python-decouple
# Successfully installed python-decouple-3.6

# %%
#020 Importamos las librerías necesarias.

import matplotlib.pyplot as plt
import numpy
import pandas as pd

import seaborn
seaborn.set_context('talk')

from decouple import config
from sqlalchemy import create_engine, text

# %%
#030 Importamos la librería plotly 
import plotly
plotly.__version__
# Make sure it's 4.14.3
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Ejercicio 1 SQL:
#
# 1. Crear una base de datos en SQLite utilizando la libreria [SQLalchemy](https://stackoverflow.com/questions/2268050/execute-sql-from-file-in-sqlalchemy).
# https://docs.sqlalchemy.org/en/14/core/engines.html#sqlite
#
# 2. Ingestar los datos provistos en 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv' en una tabla y el dataset generado en clase con datos de airbnb y sus precios por codigo postal en otra.
#
# 3. Implementar consultas en SQL que respondan con la siguiente información:
#
#     - cantidad de registros totales por ciudad.
#     - cantidad de registros totales por barrio y ciudad.
#
# 4. Combinar los datasets de ambas tablas ingestadas utilizando el comando JOIN de SQL  para obtener un resultado similar a lo realizado con Pandas en clase.

# %% [markdown]
# #Ejercicio 1 punto 1
# Crear una base de datos en SQLite utilizando la libreria SQLalchemy. https://docs.sqlalchemy.org/en/14/core/engines.html#sqlite

# %%
#040 Creamos una base de datos en SQLite utilizando la libreria SQLalchemy.  Melbourne, Australia
from sqlalchemy import create_engine, text
engine = create_engine('sqlite:///sysarmy.sqlite3', echo=True)

# %% [markdown]
# #Ejercicio 1 punto 2
# Ingestar los datos provistos en 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv' en una tabla y el dataset generado en clase con datos de airbnb y sus precios por codigo postal en otra.
#
# **Implemntado en el punto #040 y como resultado se crea el dataframe melb_df**

# %%
#050 Cargamos el conjunto de datos de la compentencia Kaggle sobre estimación de precios de ventas de propiedades en Melbourne, Australia.
melb_df = pd.read_csv(
    'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv')
melb_df[:3]
# Out:
#        Suburb          Address  Rooms Type        Price Method SellerG  \
# 0  Abbotsford     85 Turner St      2    h 1,480,000.00      S  Biggin
# 1  Abbotsford  25 Bloomburg St      2    h 1,035,000.00      S  Biggin
# 2  Abbotsford     5 Charles St      3    h 1,465,000.00     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016      2.50  3,067.00  ...      1.00 1.00    202.00           NaN
# 1  4/02/2016      2.50  3,067.00  ...      1.00 0.00    156.00         79.00
# 2  4/03/2017      2.50  3,067.00  ...      2.00 0.00    134.00        150.00
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra    -37.80      145.00  Northern Metropolitan
# 1   1,900.00        Yarra    -37.81      144.99  Northern Metropolitan
# 2   1,900.00        Yarra    -37.81      144.99  Northern Metropolitan
#
#   Propertycount
# 0      4,019.00
# 1      4,019.00
# 2      4,019.00
#
# [3 rows x 21 columns]

# %%
#060 Verificamos los cuales son los suburbios
melb_df["Suburb"].unique()
# Out:
# array(['Abbotsford', 'Airport West', 'Albert Park', 'Alphington',
#        'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton',
#        'Ashwood', 'Avondale Heights', 'Balaclava', 'Balwyn',
#        'Balwyn North', 'Bentleigh', 'Bentleigh East', 'Box Hill',
#        'Braybrook', 'Brighton', 'Brighton East', 'Brunswick',
#        'Brunswick West', 'Bulleen', 'Burwood', 'Camberwell', 'Canterbury',
#        'Carlton North', 'Carnegie', 'Caulfield', 'Caulfield North',
#        'Caulfield South', 'Chadstone', 'Clifton Hill', 'Coburg',
#        'Coburg North', 'Collingwood', 'Doncaster', 'Eaglemont',
#        'Elsternwick', 'Elwood', 'Essendon', 'Essendon North', 'Fairfield',
#        'Fitzroy', 'Fitzroy North', 'Flemington', 'Footscray', 'Glen Iris',
#        'Glenroy', 'Gowanbrae', 'Hadfield', 'Hampton', 'Hampton East',
#        'Hawthorn', 'Heidelberg Heights', 'Heidelberg West', 'Hughesdale',
#        'Ivanhoe', 'Kealba', 'Keilor East', 'Kensington', 'Kew',
#        'Kew East', 'Kooyong', 'Maidstone', 'Malvern', 'Malvern East',
#        'Maribyrnong', 'Melbourne', 'Middle Park', 'Mont Albert',
#        'Moonee Ponds', 'Moorabbin', 'Newport', 'Niddrie',
#        'North Melbourne', 'Northcote', 'Oak Park', 'Oakleigh South',
#        'Parkville', 'Pascoe Vale', 'Port Melbourne', 'Prahran', 'Preston',
#        'Reservoir', 'Richmond', 'Rosanna', 'Seddon', 'South Melbourne',
#        'South Yarra', 'Southbank', 'Spotswood', 'St Kilda', 'Strathmore',
#        'Sunshine', 'Sunshine North', 'Sunshine West', 'Surrey Hills',
#        'Templestowe Lower', 'Thornbury', 'Toorak', 'Viewbank', 'Watsonia',
#        'West Melbourne', 'Williamstown', 'Williamstown North', 'Windsor',
#        'Yallambie', 'Yarraville', 'Aberfeldie', 'Bellfield',
#        'Brunswick East', 'Burnley', 'Campbellfield', 'Carlton',
#        'East Melbourne', 'Essendon West', 'Fawkner', 'Hawthorn East',
#        'Heidelberg', 'Ivanhoe East', 'Jacana', 'Kingsbury', 'Kingsville',
#        'Murrumbeena', 'Ormond', 'West Footscray', 'Albion', 'Brooklyn',
#        'Glen Huntly', 'Oakleigh', 'Ripponlea', 'Cremorne', 'Docklands',
#        'South Kingsville', 'Strathmore Heights', 'Travancore',
#        'Caulfield East', 'Seaholme', 'Keilor Park', 'Gardenvale',
#        'Princes Hill', 'Bayswater', 'Bayswater North', 'Beaumaris',
#        'Berwick', 'Boronia', 'Briar Hill', 'Broadmeadows', 'Bundoora',
#        'Burnside Heights', 'Burwood East', 'Cairnlea', 'Caroline Springs',
#        'Cheltenham', 'Craigieburn', 'Cranbourne', 'Croydon', 'Dandenong',
#        'Dandenong North', 'Diamond Creek', 'Dingley Village',
#        'Doncaster East', 'Donvale', 'Doreen', 'Eltham', 'Epping',
#        'Forest Hill', 'Frankston', 'Frankston North', 'Frankston South',
#        'Gisborne', 'Gladstone Park', 'Greensborough', 'Hallam',
#        'Healesville', 'Highett', 'Hillside', 'Huntingdale',
#        'Keilor Downs', 'Keilor Lodge', 'Keysborough', 'Kings Park',
#        'Lalor', 'Lower Plenty', 'Melton', 'Mernda', 'Mill Park',
#        'Mitcham', 'Montmorency', 'Mordialloc', 'Mount Waverley',
#        'Narre Warren', 'Nunawading', 'Oakleigh East', 'Parkdale',
#        'Point Cook', 'Ringwood East', 'Rockbank', 'Rowville',
#        'Sandringham', 'Seaford', 'Skye', 'South Morang', 'Springvale',
#        'St Albans', 'Sunbury', 'Tarneit', 'Taylors Hill', 'Taylors Lakes',
#        'The Basin', 'Thomastown', 'Truganina', 'Tullamarine', 'Vermont',
#        'Wantirna', 'Wantirna South', 'Werribee', 'Westmeadows',
#        'Williams Landing', 'Wollert', 'Wyndham Vale', 'Black Rock',
#        'Blackburn', 'Blackburn North', 'Bonbeach', 'Carrum', 'Chelsea',
#        'Clayton', 'Doveton', 'Ferntree Gully', 'Glen Waverley',
#        'Greenvale', 'Heathmont', 'Hoppers Crossing', 'McKinnon',
#        'Melton South', 'Melton West', 'Mentone', 'Mooroolbark',
#        'Mulgrave', 'Ringwood', 'Roxburgh Park', 'Seabrook', 'Templestowe',
#        'Vermont South', 'Warrandyte', 'Watsonia North', 'Wheelers Hill',
#        'Altona Meadows', 'Blackburn South', 'Carrum Downs',
#        'Clayton South', 'Croydon North', 'Langwarrin', 'Noble Park',
#        'Notting Hill', 'Ringwood North', 'Sydenham', 'Albanvale',
#        'Beaconsfield Upper', 'Chelsea Heights', 'Dallas', 'Deer Park',
#        'Eltham North', 'Keilor', 'Meadow Heights', 'Mount Evelyn',
#        'North Warrandyte', 'Pakenham', 'Riddells Creek', 'Sandhurst',
#        'Scoresby', 'Silvan', 'Aspendale', 'Chirnside Park',
#        'Croydon Hills', 'Croydon South', 'Derrimut', 'Diggers Rest',
#        'Edithvale', 'Hampton Park', 'Knoxfield', 'St Helena', 'Upwey',
#        'Bacchus Marsh', 'Coolaroo', 'Cranbourne North', 'Kilsyth',
#        'Montrose', 'Aspendale Gardens', 'Bullengarook', 'Clarinda',
#        'Deepdene', 'Delahey', 'Hurstbridge', 'Kurunjang', 'Wonga Park',
#        'Endeavour Hills', 'Officer', 'Waterways', 'Ardeer',
#        'Beaconsfield', 'Springvale South', 'Yarra Glen', 'Brookfield',
#        'Emerald', 'Whittlesea', 'Burnside', 'Attwood', 'Wallan',
#        'New Gisborne', 'Plumpton', 'Monbulk'], dtype=object)

# %%
#070 Convertimos nuestro dataframe en una base de datos en SQL
melb_df.to_sql('Melbourne', con=engine, if_exists="replace")
# Out:
# 2022-06-07 21:36:37,920 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Melbourne")
# 2022-06-07 21:36:37,923 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 21:36:37,926 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Melbourne")
# 2022-06-07 21:36:37,929 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 21:36:37,938 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-07 21:36:37,941 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Melbourne" (
# 	"index" BIGINT,
# 	"Suburb" TEXT,
# 	"Address" TEXT,
# 	"Rooms" BIGINT,
# 	"Type" TEXT,
# 	"Price" FLOAT,
# 	"Method" TEXT,
# 	"SellerG" TEXT,
# 	"Date" TEXT,
# 	"Distance" FLOAT,
# 	"Postcode" FLOAT,
# 	"Bedroom2" FLOAT,
# 	"Bathroom" FLOAT,
# 	"Car" FLOAT,
# 	"Landsize" FLOAT,
# 	"BuildingArea" FLOAT,
# 	"YearBuilt" FLOAT,
# 	"CouncilArea" TEXT,
# 	"Lattitude" FLOAT,
# 	"Longtitude" FLOAT,
# 	"Regionname" TEXT,
# 	"Propertycount" FLOAT
# )
#
#
# 2022-06-07 21:36:37,943 INFO sqlalchemy.engine.Engine [no key 0.00196s] ()
# 2022-06-07 21:36:37,960 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Melbourne_index" ON "Melbourne" ("index")
# 2022-06-07 21:36:37,962 INFO sqlalchemy.engine.Engine [no key 0.00213s] ()
# 2022-06-07 21:36:37,977 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-07 21:36:38,010 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-07 21:36:38,496 INFO sqlalchemy.engine.Engine INSERT INTO "Melbourne" ("index", "Suburb", "Address", "Rooms", "Type", "Price", "Method", "SellerG", "Date", "Distance", "Postcode", "Bedroom2", "Bathroom", "Car", "Landsize", "BuildingArea", "YearBuilt", "CouncilArea", "Lattitude", "Longtitude", "Regionname", "Propertycount") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-06-07 21:36:38,498 INFO sqlalchemy.engine.Engine [generated in 0.43219s] ((0, 'Abbotsford', '85 Turner St', 2, 'h', 1480000.0, 'S', 'Biggin', '3/12/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 202.0, None, None, 'Yarra', -37.7996, 144.9984, 'Northern Metropolitan', 4019.0), (1, 'Abbotsford', '25 Bloomburg St', 2, 'h', 1035000.0, 'S', 'Biggin', '4/02/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 156.0, 79.0, 1900.0, 'Yarra', -37.8079, 144.9934, 'Northern Metropolitan', 4019.0), (2, 'Abbotsford', '5 Charles St', 3, 'h', 1465000.0, 'SP', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 0.0, 134.0, 150.0, 1900.0, 'Yarra', -37.8093, 144.9944, 'Northern Metropolitan', 4019.0), (3, 'Abbotsford', '40 Federation La', 3, 'h', 850000.0, 'PI', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 1.0, 94.0, None, None, 'Yarra', -37.7969, 144.9969, 'Northern Metropolitan', 4019.0), (4, 'Abbotsford', '55a Park St', 4, 'h', 1600000.0, 'VB', 'Nelson', '4/06/2016', 2.5, 3067.0, 3.0, 1.0, 2.0, 120.0, 142.0, 2014.0, 'Yarra', -37.8072, 144.9941, 'Northern Metropolitan', 4019.0), (5, 'Abbotsford', '129 Charles St', 2, 'h', 941000.0, 'S', 'Jellis', '7/05/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 181.0, None, None, 'Yarra', -37.8041, 144.9953, 'Northern Metropolitan', 4019.0), (6, 'Abbotsford', '124 Yarra St', 3, 'h', 1876000.0, 'S', 'Nelson', '7/05/2016', 2.5, 3067.0, 4.0, 2.0, 0.0, 245.0, 210.0, 1910.0, 'Yarra', -37.8024, 144.9993, 'Northern Metropolitan', 4019.0), (7, 'Abbotsford', '98 Charles St', 2, 'h', 1636000.0, 'S', 'Nelson', '8/10/2016', 2.5, 3067.0, 2.0, 1.0, 2.0, 256.0, 107.0, 1890.0, 'Yarra', -37.806, 144.9954, 'Northern Metropolitan', 4019.0)  ... displaying 10 of 13580 total bound parameter sets ...  (13578, 'Williamstown', '96 Verdon St', 4, 'h', 2500000.0, 'PI', 'Sweeney', '26/08/2017', 6.8, 3016.0, 4.0, 1.0, 5.0, 866.0, 157.0, 1920.0, None, -37.85908, 144.89299, 'Western Metropolitan', 6380.0), (13579, 'Yarraville', '6 Agnes St', 4, 'h', 1285000.0, 'SP', 'Village', '26/08/2017', 6.3, 3013.0, 4.0, 1.0, 1.0, 362.0, 112.0, 1920.0, None, -37.81188, 144.88449, 'Western Metropolitan', 6543.0))
# 2022-06-07 21:36:38,616 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-07 21:36:38,651 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-06-07 21:36:38,652 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
#080 Verificamos cuales son las columnas de Airbnb
airbnb_df = pd.read_csv(
    'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/cleansed_listings_dec18.csv')
print(airbnb_df.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'neighborhood_overview', 'notes', 'transit',
#        'access', 'interaction', 'house_rules', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighborhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighborhood', 'city', 'suburb', 'state', 'zipcode',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price',
#        'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'calendar_updated', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'calendar_last_scraped', 'number_of_reviews', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'license',
#        'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#090 Cargamos una base de datos  de airbnb
# data source:
# https://www.kaggle.com/tylerx/melbourne-airbnb-open-data?select=cleansed_listings_dec18.csv
interesting_cols = [
  'description', 'neighborhood_overview',
  'street', 'neighborhood', 'city', 'suburb', 'state', 'zipcode',
  'price', 'weekly_price', 'monthly_price',
  'latitude', 'longitude', 'review_scores_rating'
]
airbnb_df = pd.read_csv(
    'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/cleansed_listings_dec18.csv',
    usecols=interesting_cols)

#print(melb_df.columns)
#print(airbnb_df.columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#100 Convertimos nuestro dataframe en una base de datos en SQL
airbnb_df.to_sql('Airbnb', con=engine, if_exists="replace")
# Out:
# 2022-06-07 21:37:07,560 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Airbnb")
# 2022-06-07 21:37:07,564 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 21:37:07,568 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Airbnb")
# 2022-06-07 21:37:07,570 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 21:37:07,580 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-07 21:37:07,584 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Airbnb" (
# 	"index" BIGINT,
# 	description TEXT,
# 	neighborhood_overview TEXT,
# 	street TEXT,
# 	neighborhood TEXT,
# 	city TEXT,
# 	suburb TEXT,
# 	state TEXT,
# 	zipcode TEXT,
# 	latitude FLOAT,
# 	longitude FLOAT,
# 	price BIGINT,
# 	weekly_price FLOAT,
# 	monthly_price FLOAT,
# 	review_scores_rating FLOAT
# )
#
#
# 2022-06-07 21:37:07,587 INFO sqlalchemy.engine.Engine [no key 0.00260s] ()
# 2022-06-07 21:37:07,604 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Airbnb_index" ON "Airbnb" ("index")
# 2022-06-07 21:37:07,607 INFO sqlalchemy.engine.Engine [no key 0.00301s] ()
# 2022-06-07 21:37:07,622 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-07 21:37:07,700 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-07 21:37:09,529 INFO sqlalchemy.engine.Engine INSERT INTO "Airbnb" ("index", description, neighborhood_overview, street, neighborhood, city, suburb, state, zipcode, latitude, longitude, price, weekly_price, monthly_price, review_scores_rating) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-06-07 21:37:09,531 INFO sqlalchemy.engine.Engine [generated in 1.70555s] ((0, 'House: Clean, New, Modern, Quite, Safe. 10Km from the City. Golf course, Tennis courts, bus stop & shops walking distance!! Rooms: Contains one queen ... (702 characters truncated) ... pproximately what your daily in and out hours might look like.  Note: There is a 5 year old fun loving dog who lives with us and is part of our famil', 'Very safe! Family oriented. Older age group.', 'Bulleen, VIC, Australia', 'Balwyn North', 'Manningham', 'Bulleen', 'VIC', '3105', -37.77268393, 145.0921328, 60, None, None, 90.0), (1, "A large air conditioned room with queen spring mattress bed in a vintage apartment. Located right outside is a tram to the city just 19 minutes away. ... (702 characters truncated) ... ou east to Bundoora and west to Pacoevale. The Lygon Street tram line that goes past Melbourne University is 10 minutes walk west and Sydney Road and", "This hip area is a crossroads between two great cultural strips of inner Northern Melbourne.  Located in East Brunswick, between High St, Northcote a ... (533 characters truncated) ... re three coffee places within 50metres, and the Lomond Hotel Pub right across the road has good live music and there's also a pizza place downstairs.", 'Brunswick East, VIC, Australia', 'Brunswick', 'Moreland', 'Brunswick East', 'VIC', '3057', -37.76650512, 144.9807361, 35, 200.0, 803.0, 87.0), (2, 'RIGHT IN THE HEART OF ST KILDA! It doesn\'t get more central than this! A fabulous north facing balcony apartment that offers right in the heart of t ... (703 characters truncated) ... system with iPod dock & DVD/CD player Selection of books, magazines, DVDs, CDs Glass framed console/desk with lamp Bedroom with queen bed, hotel qual', 'A stay at our apartment means you can enjoy some of Melbourne’s best restaurants, bars, cafes, shopping, dining and night life, all at your doorstep. ... (288 characters truncated) ... ith the city skyline as a stunning backdrop. Our apartment is perfectly suited to those wanting an exclusive, authentic urban residential experience.', 'St Kilda, VIC, Australia', 'St Kilda', 'Port Phillip', 'St Kilda', 'VIC', '3182', -37.85975502, 144.9773691, 159, 1253.0, 4452.0, 94.0), (3, "Comfortable, relaxed house, a home away from  home! This is a shared house, you will be sharing with me, plus the occasional other guest. Rooms are l ... (702 characters truncated) ... om, watch a movie, or TV, or relax in the back yard. Guest's privacy will be respected at all times. If you need information and tips on where to go,", 'This is a great neighbourhood – it is quiet, yet close to so many things. High Street, Northcote (hip bars, cafes and craft stores) are a 10 minute walk east; Sydney Road (ethnic delights and great food) is 8 minute drive west; city is 30 minutes by tram or train.', 'Thornbury, VIC, Australia', 'Thornbury', 'Darebin', 'Thornbury', 'VIC', '3071', -37.75897072, 144.9892279, 50, 250.0, 920.0, 94.0), (4, 'We offer comfortable accommodation in Inner Melbourne in Clement House, a two storey Victorian built in 1888. Large double bedroom with balcony, priv ... (660 characters truncated) ... n smoking house with an outside courtyard for smokers. The rate for guests that stay for a week are heavily discounted and therefore very attractive.', None, 'St Kilda East, VIC, Australia', 'St Kilda East', 'Port Phillip', 'St Kilda East', 'VIC', '3183', -37.8645303, 144.9922379, 69, 400.0, 1900.0, 90.0), (5, 'Please note: No booking will be accepted with children under the age of 13 years.  Accommodation is non smoking in apartment & on grounds.  All visit ... (702 characters truncated) ... om, toilet & living area with stereo and 32" LCD TV. A second bedroom (Autumn Room) is available with another Queen size bed for extra travelers if r', 'Our street is quiet & secluded but within walking distance to almost anything you need.', 'Berwick, VIC, Australia', None, 'Casey', 'Berwick', 'VIC', '3806', -38.05725414,  ...
# 2022-06-07 21:37:09,820 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-07 21:37:09,943 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-06-07 21:37:09,945 INFO sqlalchemy.engine.Engine [raw sql] ()

# %% [markdown]
# #Ejercicio 1 punto 3
#
# Implementar consultas en SQL que respondan con la siguiente información:
#
#
#
# *   Cantidad de registros totales por ciudad.
# *   Cantidad de registros totales por barrio y ciudad.

# %%
#110 Creamos funciones para ejecutar las queries
def execute_print_sql(list_of_sql_sentences):
    with engine.connect() as con:
        for query in list_of_sql_sentences:
            rs = con.execute(query)
            print(query)
            for row in rs:
                print(row)
            print('\n\n')

def execute_sql(query):
    with engine.connect() as con:
        rs = con.execute(query)
        return rs

# %%
#120 cantidad de registros totales por codigo postal y por Suburbios en tabla Melbourne.
query1 = "SELECT Postcode, COUNT(1) FROM Melbourne GROUP BY Postcode"
query2 = "SELECT Postcode, Suburb, COUNT(1) FROM Melbourne GROUP BY Postcode, Suburb"
queries = [query1, query2]

# %%
#130 Implementamos las consultas SQL en la base de datos Melbourne
execute_print_sql(queries)
# Out:
# 2022-06-07 21:37:09,999 INFO sqlalchemy.engine.Engine SELECT Postcode, COUNT(1) FROM Melbourne GROUP BY Postcode
# 2022-06-07 21:37:10,001 INFO sqlalchemy.engine.Engine [raw sql] ()
# SELECT Postcode, COUNT(1) FROM Melbourne GROUP BY Postcode
# (3000.0, 46)
# (3002.0, 22)
# (3003.0, 31)
# (3006.0, 41)
# (3008.0, 3)
# (3011.0, 194)
# (3012.0, 242)
# (3013.0, 164)
# (3015.0, 188)
# (3016.0, 126)
# (3018.0, 80)
# (3019.0, 46)
# (3020.0, 306)
# (3021.0, 55)
# (3022.0, 3)
# (3023.0, 37)
# (3024.0, 4)
# (3025.0, 56)
# (3027.0, 2)
# (3028.0, 9)
# (3029.0, 53)
# (3030.0, 68)
# (3031.0, 179)
# (3032.0, 236)
# (3033.0, 121)
# (3034.0, 74)
# (3036.0, 9)
# (3037.0, 36)
# (3038.0, 39)
# (3039.0, 149)
# (3040.0, 290)
# (3041.0, 91)
# (3042.0, 171)
# (3043.0, 57)
# (3044.0, 171)
# (3046.0, 284)
# (3047.0, 54)
# (3048.0, 21)
# (3049.0, 15)
# (3051.0, 81)
# (3052.0, 31)
# (3053.0, 51)
# (3054.0, 53)
# (3055.0, 110)
# (3056.0, 222)
# (3057.0, 88)
# (3058.0, 246)
# (3059.0, 17)
# (3060.0, 102)
# (3061.0, 4)
# (3064.0, 62)
# (3065.0, 59)
# (3066.0, 65)
# (3067.0, 56)
# (3068.0, 150)
# (3070.0, 188)
# (3071.0, 139)
# (3072.0, 239)
# (3073.0, 359)
# (3074.0, 29)
# (3075.0, 42)
# (3076.0, 52)
# (3078.0, 77)
# (3079.0, 123)
# (3081.0, 170)
# (3082.0, 43)
# (3083.0, 49)
# (3084.0, 176)
# (3085.0, 24)
# (3087.0, 62)
# (3088.0, 47)
# (3089.0, 6)
# (3093.0, 5)
# (3094.0, 17)
# (3095.0, 38)
# (3099.0, 2)
# (3101.0, 177)
# (3102.0, 49)
# (3103.0, 109)
# (3104.0, 171)
# (3105.0, 71)
# (3106.0, 19)
# (3107.0, 92)
# (3108.0, 116)
# (3109.0, 41)
# (3111.0, 13)
# (3113.0, 7)
# (3115.0, 1)
# (3116.0, 2)
# (3121.0, 292)
# (3122.0, 191)
# (3123.0, 119)
# (3124.0, 132)
# (3125.0, 84)
# (3126.0, 54)
# (3127.0, 159)
# (3128.0, 59)
# (3130.0, 47)
# (3131.0, 42)
# (3132.0, 30)
# (3133.0, 27)
# (3134.0, 30)
# (3135.0, 28)
# (3136.0, 45)
# (3137.0, 4)
# (3138.0, 12)
# (3141.0, 202)
# (3142.0, 100)
# (3143.0, 95)
# (3144.0, 69)
# (3145.0, 126)
# (3146.0, 195)
# (3147.0, 106)
# (3148.0, 35)
# (3149.0, 57)
# (3150.0, 71)
# (3151.0, 16)
# (3152.0, 34)
# (3153.0, 22)
# (3154.0, 4)
# (3155.0, 14)
# (3156.0, 22)
# (3158.0, 1)
# (3161.0, 35)
# (3162.0, 59)
# (3163.0, 245)
# (3165.0, 249)
# (3166.0, 100)
# (3167.0, 58)
# (3168.0, 16)
# (3169.0, 15)
# (3170.0, 29)
# (3171.0, 9)
# (3172.0, 24)
# (3173.0, 11)
# (3174.0, 12)
# (3175.0, 29)
# (3177.0, 7)
# (3178.0, 10)
# (3179.0, 8)
# (3180.0, 4)
# (3181.0, 183)
# (3182.0, 162)
# (3183.0, 27)
# (3184.0, 131)
# (3185.0, 76)
# (3186.0, 186)
# (3187.0, 138)
# (3188.0, 155)
# (3189.0, 64)
# (3190.0, 27)
# (3191.0, 25)
# (3192.0, 46)
# (3193.0, 30)
# (3194.0, 26)
# (3195.0, 55)
# (3196.0, 22)
# (3197.0, 9)
# (3198.0, 14)
# (3199.0, 40)
# (3200.0, 4)
# (3201.0, 12)
# (3204.0, 230)
# (3205.0, 85)
# (3206.0, 103)
# (3207.0, 153)
# (3335.0, 2)
# (3337.0, 24)
# (3338.0, 19)
# (3340.0, 1)
# (3427.0, 2)
# (3429.0, 38)
# (3431.0, 1)
# (3437.0, 9)
# (3438.0, 1)
# (3750.0, 9)
# (3752.0, 21)
# (3754.0, 15)
# (3756.0, 1)
# (3757.0, 1)
# (3765.0, 1)
# (3775.0, 1)
# (3777.0, 1)
# (3782.0, 1)
# (3793.0, 1)
# (3795.0, 2)
# (3796.0, 2)
# (3802.0, 5)
# (3803.0, 5)
# (3805.0, 7)
# (3806.0, 13)
# (3807.0, 2)
# (3808.0, 1)
# (3809.0, 1)
# (3810.0, 3)
# (3910.0, 6)
# (3976.0, 4)
# (3977.0, 8)
#
#
#
# 2022-06-07 21:37:10,147 INFO sqlalchemy.engine.Engine SELECT Postcode, Suburb, COUNT(1) FROM Melbourne GROUP BY Postcode, Suburb
# 2022-06-07 21:37:10,151 INFO sqlalchemy.engine.Engine [raw sql] ()
# SELECT Postcode, Suburb, COUNT(1) FROM Melbourne GROUP BY Postcode, Suburb
# (3000.0, 'Melbourne', 46)
# (3002.0, 'East Melbourne', 22)
# (3003.0, 'West Melbourne', 31)
# (3006.0, 'Southbank', 41)
# (3008.0, 'Docklands', 3)
# (3011.0, 'Footscray', 132)
# (3011.0, 'Seddon', 62)
# (3012.0, 'Brooklyn', 9)
# (3012.0, 'Kingsville', 34)
# (3012.0, 'Maidstone', 94)
# (3012.0, 'West Footscray', 105)
# (3013.0, 'Yarraville', 164)
# (3015.0, 'Newport', 137)
# (3015.0, 'South Kingsville', 22)
# (3015.0, 'Spotswood', 29)
# (3016.0, 'Williamstown', 107)
# (3016.0, 'Williamstown North', 19)
# (3018.0, 'Altona', 74)
# (3018.0, 'Seaholme', 6)
# (3019.0, 'Braybrook', 46)
# (3020.0, 'Albion', 41)
# (3020.0, 'Sunshine', 111)
# (3020.0, 'Sunshine North', 68)
# (3020.0, 'Sunshine West', 86)
# (3021.0, 'Albanvale', 6)
# (3021.0, 'Kealba', 19)
# (3021.0, 'Kings Park', 5)
# (3021.0, 'St Albans', 25)
# (3022.0, 'Ardeer', 3)
# (3023.0, 'Burnside', 2)
# (3023.0, 'Burnside Heights', 3)
# (3023.0, 'Cairnlea', 7)
# (3023.0, 'Caroline Springs', 11)
# (3023.0, 'Deer Park', 14)
# (3024.0, 'Wyndham Vale', 4)
# (3025.0, 'Altona North', 56)
# (3027.0, 'Williams Landing', 2)
# (3028.0, 'Altona Meadows', 6)
# (3028.0, 'Seabrook', 3)
# (3029.0, 'Hoppers Crossing', 38)
# (3029.0, 'Tarneit', 10)
# (3029.0, 'Truganina', 5)
# (3030.0, 'Derrimut', 5)
# (3030.0, 'Point Cook', 13)
# (3030.0, 'Werribee', 50)
# (3031.0, 'Flemington', 62)
# (3031.0, 'Kensington', 117)
# (3032.0, 'Ascot Vale', 130)
# (3032.0, 'Maribyrnong', 96)
# (3032.0, 'Travancore', 10)
# (3033.0, 'Keilor East', 121)
# (3034.0, 'Avondale Heights', 74)
# (3036.0, 'Keilor', 9)
# (3037.0, 'Delahey', 6)
# (3037.0, 'Hillside', 18)
# (3037.0, 'Sydenham', 5)
# (3037.0, 'Taylors Hill', 7)
# (3038.0, 'Keilor Downs', 15)
# (3038.0, 'Keilor Lodge', 2)
# (3038.0, 'Taylors Lakes', 22)
# (3039.0, 'Moonee Ponds', 149)
# (3040.0, 'Aberfeldie', 44)
# (3040.0, 'Essendon', 220)
# (3040.0, 'Essendon West', 26)
# (3041.0, 'Essendon North', 22)
# (3041.0, 'Strathmore', 63)
# (3041.0, 'Strathmore Heights', 6)
# (3042.0, 'Airport West', 67)
# (3042.0, 'Keilor Park', 22)
# (3042.0, 'Niddrie', 82)
# (3043.0, 'Gladstone Park', 20)
# (3043.0, 'Gowanbrae', 24)
# (3043.0, 'Tullamarine', 13)
# (3044.0, 'Pascoe Vale', 171)
# (3046.0, 'Glenroy', 159)
# (3046.0, 'Hadfield', 62)
# (3046.0, 'Oak Park', 63)
# (3047.0, 'Broadmeadows', 23)
# (3047.0, 'Dallas', 6)
# (3047.0, 'Jacana', 25)
# (3048.0, 'Coolaroo', 4)
# (3048.0, 'Meadow Heights', 17)
# (3049.0, 'Attwood', 1)
# (3049.0, 'Westmeadows', 14)
# (3051.0, 'North Melbourne', 81)
# (3052.0, 'Parkville', 31)
# (3053.0, 'Carlton', 51)
# (3054.0, 'Carlton North', 48)
# (3054.0, 'Princes Hill', 5)
# (3055.0, 'Brunswick West', 110)
# (3056.0, 'Brunswick', 222)
# (3057.0, 'Brunswick East', 88)
# (3058.0, 'Coburg', 190)
# (3058.0, 'Coburg North', 56)
# (3059.0, 'Greenvale', 17)
# (3060.0, 'Fawkner', 102)
# (3061.0, 'Campbellfield', 4)
# (3064.0, 'Craigieburn', 47)
# (3064.0, 'Roxburgh Park', 15)
# (3065.0, 'Fitzroy', 59)
# (3066.0, 'Collingwood', 65)
# (3067.0, 'Abbotsford', 56)
# (3068.0, 'Clifton Hill', 57)
# (3068.0, 'Fitzroy North', 93)
# (3070.0, 'Northcote', 188)
# (3071.0, 'Thornbury', 139)
# (3072.0, 'Preston', 239)
# (3073.0, 'Reservoir', 359)
# (3074.0, 'Thomastown', 29)
# (3075.0, 'Lalor', 42)
# (3076.0, 'Epping', 52)
# (3078.0, 'Alphington', 34)
# (3078.0, 'Fairfield', 43)
# (3079.0, 'Ivanhoe', 98)
# (3079.0, 'Ivanhoe East', 25)
# (3081.0, 'Bellfield', 16)
# (3081.0, 'Heidelberg Heights', 78)
# (3081.0, 'Heidelberg West', 76)
# (3082.0, 'Mill Park', 43)
# (3083.0, 'Bundoora', 36)
# (3083.0, 'Kingsbury', 13)
# (3084.0, 'Eaglemont', 23)
# (3084.0, 'Heidelberg', 51)
# (3084.0, 'Rosanna', 61)
# (3084.0, 'Viewbank', 41)
# (3085.0, 'Yallambie', 24)
# (3087.0, 'Watsonia', 52)
# (3087.0, 'Watsonia North', 10)
# (3088.0, 'Briar Hill', 8)
# (3088.0, 'Greensborough', 36)
# (3088.0, 'St Helena', 3)
# (3089.0, 'Diamond Creek', 6)
# (3093.0, 'Lower Plenty', 5)
# (3094.0, 'Montmorency', 17)
# (3095.0, 'Eltham', 25)
# (3095.0, 'Eltham North', 13)
# (3099.0, 'Hurstbridge', 2)
# (3101.0, 'Kew', 177)
# (3102.0, 'Kew East', 49)
# (3103.0, 'Balwyn', 107)
# (3103.0, 'Deepdene', 2)
# (3104.0, 'Balwyn North', 171)
# (3105.0, 'Bulleen', 71)
# (3106.0, 'Templestowe', 19)
# (3107.0, 'Templestowe Lower', 92)
# (3108.0, 'Doncaster', 116)
# (3109.0, 'Doncaster East', 41)
# (3111.0, 'Donvale', 13)
# (3113.0, 'North Warrandyte', 2)
# (3113.0, 'Warrandyte', 5)
# (3115.0, 'Wonga Park', 1)
# (3116.0, 'Chirnside Park', 2)
# (3121.0, 'Burnley', 7)
# (3121.0, 'Cremorne', 25)
# (3121.0, 'Richmond', 260)
# (3122.0, 'Hawthorn', 191)
# (3123.0, 'Hawthorn East', 119)
# (3124.0, 'Camberwell', 132)
# (3125.0, 'Burwood', 84)
# (3126.0, 'Canterbury', 54)
# (3127.0, 'Mont Albert', 34)
# (3127.0, 'Surrey Hills', 125)
# (3128.0, 'Box Hill', 59)
# (3130.0, 'Blackburn', 21)
# (3130.0, 'Blackburn North', 14)
# (3130.0, 'Blackburn South', 12)
# (3131.0, 'Forest Hill', 22)
# (3131.0, 'Nunawading', 20)
# (3132.0, 'Mitcham', 30)
# (3133.0, 'Vermont', 14)
# (3133.0, 'Vermont South', 13)
# (3134.0, 'Ringwood', 20)
# (3134.0, 'Ringwood North', 10)
# (3135.0, 'Heathmont', 16)
# (3135.0, 'Ringwood East', 12)
# (3136.0, 'Croydon', 33)
# (3136.0, 'Croydon Hills', 4)
# (3136.0, 'Croydon North', 7)
# (3136.0, 'Croydon South', 1)
# (3137.0, 'Kilsyth', 4)
# (3138.0, 'Mooroolbark', 12)
# (3141.0, 'South Yarra', 202)
# (3142.0, 'Toorak', 100)
# (3143.0, 'Armadale', 95)
# (3144.0, 'Kooyong', 2)
# (3144.0, 'Malvern', 67)
# (3145.0, 'Caulfield East', 9)
# (3145.0, 'Malvern East', 117)
# (3146.0, 'Glen Iris', 195)
# (3147.0, 'Ashburton', 60)
# (3147.0, 'Ashwood', 46)
# (3148.0, 'Chadstone', 35)
# (3149.0, 'Mount Waverley', 57)
# (3150.0, 'Glen Waverley', 45)
# (3150.0, 'Wheelers Hill', 26)
# (3151.0, 'Burwood East', 16)
# (3152.0, 'Wantirna', 12)
# (3152.0, 'Wantirna South', 22)
# (3153.0, 'Bayswater', 14)
# (3153.0, 'Bayswater North', 8)
# (3154.0, 'The Basin', 4)
# (3155.0, 'Boronia', 14)
# (3156.0, 'Ferntree Gully', 22)
# (3158.0, 'Upwey', 1)
# (3161.0, 'Caulfield North', 35)
# (3162.0, 'Caulfield', 12)
# (3162.0, 'Caulfield South', 47)
# (3163.0, 'Carnegie', 146)
# (3163.0, 'Glen Huntly', 17)
# (3163.0, 'Murrumbeena', 82)
# (3165.0, 'Bentleigh East', 249)
# (3166.0, 'Hughesdale', 35)
# (3166.0, 'Huntingdale', 7)
# (3166.0, 'Oakleigh', 47)
# (3166.0, 'Oakleigh East', 11)
# (3167.0, 'Oakleigh South', 58)
# (3168.0, 'Clayton', 13)
# (3168.0, 'Notting Hill', 3)
# (3169.0, 'Clarinda', 4)
# (3169.0, 'Clayton South', 11)
# (3170.0, 'Mulgrave', 29)
# (3171.0, 'Springvale', 9)
# (3172.0, 'Dingley Village', 21)
# (3172.0, 'Springvale South', 3)
# (3173.0, 'Keysborough', 11)
# (3174.0, 'Noble Park', 12)
# (3175.0, 'Dandenong', 13)
# (3175.0, 'Dandenong North', 16)
# (3177.0, 'Doveton', 7)
# (3178.0, 'Rowville', 10)
# (3179.0, 'Scoresby', 8)
# (3180.0, 'Knoxfield', 4)
# (3181.0, 'Prahran', 123)
# (3181.0, 'Windsor', 60)
# (3182.0, 'St Kilda', 162)
# (3183.0, 'Balaclava', 27)
# (3184.0, 'Elwood', 131)
# (3185.0, 'Elsternwick', 61)
# (3185.0, 'Gardenvale', 6)
# (3185.0, 'Ripponlea', 9)
# (3186.0, 'Brighton', 186)
# (3187.0, 'Brighton East', 138)
# (3188.0, 'Hampton', 130)
# (3188.0, 'Hampton East', 25)
# (3189.0, 'Moorabbin', 64)
# (3190.0, 'Highett', 27)
# (3191.0, 'Sandringham', 25)
# (3192.0, 'Cheltenham', 46)
# (3193.0, 'Beaumaris', 18)
# (3193.0, 'Black Rock', 12)
# (3194.0, 'Mentone', 26)
# (3195.0, 'Aspendale', 7)
# (3195.0, 'Aspendale Gardens', 4)
# (3195.0, 'Mordialloc', 18)
# (3195.0, 'Parkdale', 24)
# (3195.0, 'Waterways', 2)
# (3196.0, 'Bonbeach', 4)
# (3196.0, 'Chelsea', 5)
# (3196.0, 'Chelsea Heights', 4)
# (3196.0, 'Edithvale', 9)
# (3197.0, 'Carrum', 9)
# (3198.0, 'Seaford', 14)
# (3199.0, 'Frankston', 24)
# (3199.0, 'Frankston South', 16)
# (3200.0, 'Frankston North', 4)
# (3201.0, 'Carrum Downs', 12)
# (3204.0, 'Bentleigh', 139)
# (3204.0, 'McKinnon', 8)
# (3204.0, 'Ormond', 83)
# (3205.0, 'South Melbourne', 85)
# (3206.0, 'Albert Park', 69)
# (3206.0, 'Middle Park', 34)
# (3207.0, 'Port Melbourne', 153)
# (3335.0, 'Plumpton', 1)
# (3335.0, 'Rockbank', 1)
# (3337.0, 'Kurunjang', 4)
# (3337.0, 'Melton', 12)
# (3337.0, 'Melton West', 8)
# (3338.0, 'Brookfield', 1)
# (3338.0, 'Melton South', 18)
# (3340.0, 'Bacchus Marsh', 1)
# (3427.0, 'Diggers Rest', 2)
# (3429.0, 'Sunbury', 38)
# (3431.0, 'Riddells Creek', 1)
# (3437.0, 'Bullengarook', 1)
# (3437.0, 'Gisborne', 8)
# (3438.0, 'New Gisborne', 1)
# (3750.0, 'Wollert', 9)
# (3752.0, 'South Morang', 21)
# (3754.0, 'Doreen', 6)
# (3754.0, 'Mernda', 9)
# (3756.0, 'Wallan', 1)
# (3757.0, 'Whittlesea', 1)
# (3765.0, 'Montrose', 1)
# (3775.0, 'Yarra Glen', 1)
# (3777.0, 'Healesville', 1)
# (3782.0, 'Emerald', 1)
# (3793.0, 'Monbulk', 1)
# (3795.0, 'Silvan', 2)
# (3796.0, 'Mount Evelyn', 2)
# (3802.0, 'Endeavour Hills', 5)
# (3803.0, 'Hallam', 5)
# (3805.0, 'Narre Warren', 7)
# (3806.0, 'Berwick', 13)
# (3807.0, 'Beaconsfield', 2)
# (3808.0, 'Beaconsfield Upper', 1)
# (3809.0, 'Officer', 1)
# (3810.0, 'Pakenham', 3)
# (3910.0, 'Langwarrin', 6)
# (3976.0, 'Hampton Park', 4)
# (3977.0, 'Cranbourne', 3)
# (3977.0, 'Cranbourne North', 2)
# (3977.0, 'Sandhurst', 1)
# (3977.0, 'Skye', 2)

# %%
#140 cantidad de registros totales por codigo postal en la base de datos Airbnb
# cantidad de registros totales por ciudad y por barrio en la base de datos Airbnb.

query3 = "SELECT city, COUNT(1) FROM Airbnb GROUP BY city"
query4 ="SELECT city, neighborhood, COUNT(1) FROM Airbnb GROUP BY city, neighborhood"
queries = [query3, query4]

# %%
#150 Implementamos las consultas SQL en la base de datos Airbnb
execute_print_sql(queries)
# Out:
# 2022-06-07 21:37:10,402 INFO sqlalchemy.engine.Engine SELECT city, COUNT(1) FROM Airbnb GROUP BY city
# 2022-06-07 21:37:10,404 INFO sqlalchemy.engine.Engine [raw sql] ()
# SELECT city, COUNT(1) FROM Airbnb GROUP BY city
# ('Banyule', 203)
# ('Bayside', 375)
# ('Boroondara', 664)
# ('Brimbank', 108)
# ('Cardinia', 123)
# ('Casey', 153)
# ('Darebin', 698)
# ('Frankston', 177)
# ('Glen Eira', 631)
# ('Greater Dandenong', 147)
# ('Hobsons Bay', 239)
# ('Hume', 170)
# ('Kingston', 309)
# ('Knox', 175)
# ('Manningham', 313)
# ('Maribyrnong', 436)
# ('Maroondah', 115)
# ('Melbourne', 7368)
# ('Melton', 95)
# ('Monash', 571)
# ('Moonee Valley', 344)
# ('Moreland', 967)
# ('Nillumbik', 88)
# ('Port Phillip', 2808)
# ('Stonnington', 1621)
# ('Whitehorse', 614)
# ('Whittlesea', 137)
# ('Wyndham', 426)
# ('Yarra', 2049)
# ('Yarra Ranges', 771)
#
#
#
# 2022-06-07 21:37:10,470 INFO sqlalchemy.engine.Engine SELECT city, neighborhood, COUNT(1) FROM Airbnb GROUP BY city, neighborhood
# 2022-06-07 21:37:10,472 INFO sqlalchemy.engine.Engine [raw sql] ()
# SELECT city, neighborhood, COUNT(1) FROM Airbnb GROUP BY city, neighborhood
# ('Banyule', None, 174)
# ('Banyule', 'Alphington', 16)
# ('Banyule', 'Preston', 8)
# ('Banyule', 'Thornbury', 5)
# ('Bayside', None, 170)
# ('Bayside', 'Bentleigh', 1)
# ('Bayside', 'Brighton', 203)
# ('Bayside', 'Elwood', 1)
# ('Boroondara', None, 30)
# ('Boroondara', 'Ashburton', 14)
# ('Boroondara', 'Balwyn', 70)
# ('Boroondara', 'Balwyn North', 40)
# ('Boroondara', 'Camberwell', 82)
# ('Boroondara', 'Canterbury', 24)
# ('Boroondara', 'Glen Iris', 32)
# ('Boroondara', 'Hawthorn', 261)
# ('Boroondara', 'Kew', 109)
# ('Boroondara', 'Malvern', 2)
# ('Brimbank', None, 108)
# ('Cardinia', None, 123)
# ('Casey', None, 153)
# ('Darebin', None, 112)
# ('Darebin', 'Alphington', 22)
# ('Darebin', 'Coburg', 4)
# ('Darebin', 'Northcote', 303)
# ('Darebin', 'Preston', 156)
# ('Darebin', 'Thornbury', 101)
# ('Frankston', None, 177)
# ('Glen Eira', None, 33)
# ('Glen Eira', 'Balaclava/Ripponlea', 2)
# ('Glen Eira', 'Bentleigh', 84)
# ('Glen Eira', 'Brighton', 2)
# ('Glen Eira', 'Carnegie', 126)
# ('Glen Eira', 'Caulfield', 299)
# ('Glen Eira', 'Ormond/McKinnon', 46)
# ('Glen Eira', 'St Kilda East', 39)
# ('Greater Dandenong', None, 147)
# ('Hobsons Bay', None, 90)
# ('Hobsons Bay', 'Newport', 45)
# ('Hobsons Bay', 'Spotswood/South Kingsville', 23)
# ('Hobsons Bay', 'Williamstown', 75)
# ('Hobsons Bay', 'Yarraville/Seddon', 6)
# ('Hume', None, 170)
# ('Kingston', None, 292)
# ('Kingston', 'Bentleigh', 17)
# ('Knox', None, 175)
# ('Manningham', None, 296)
# ('Manningham', 'Balwyn North', 17)
# ('Maribyrnong', None, 57)
# ('Maribyrnong', 'Footscray', 253)
# ('Maribyrnong', 'Yarraville/Seddon', 126)
# ('Maroondah', None, 115)
# ('Melbourne', None, 241)
# ('Melbourne', 'Brunswick', 7)
# ('Melbourne', 'Carlton', 582)
# ('Melbourne', 'Carlton North', 10)
# ('Melbourne', 'Central Business District', 3726)
# ('Melbourne', 'Docklands', 576)
# ('Melbourne', 'East Melbourne', 180)
# ('Melbourne', 'Flemington', 12)
# ('Melbourne', 'Kensington', 107)
# ('Melbourne', 'North Melbourne', 290)
# ('Melbourne', 'Parkville', 85)
# ('Melbourne', 'Port Melbourne', 8)
# ('Melbourne', 'Prahran/Windsor', 35)
# ('Melbourne', 'South Melbourne', 1)
# ('Melbourne', 'South Wharf', 24)
# ('Melbourne', 'South Yarra', 161)
# ('Melbourne', 'Southbank', 1204)
# ('Melbourne', 'West Melbourne', 119)
# ('Melton', None, 95)
# ('Monash', None, 516)
# ('Monash', 'Ashburton', 4)
# ('Monash', 'Bentleigh', 5)
# ('Monash', 'Carnegie', 24)
# ('Monash', 'Glen Iris', 5)
# ('Monash', 'Malvern East', 17)
# ('Moonee Valley', None, 144)
# ('Moonee Valley', 'Brunswick', 33)
# ('Moonee Valley', 'Flemington', 166)
# ('Moonee Valley', 'Kensington', 1)
# ('Moreland', None, 136)
# ('Moreland', 'Brunswick', 681)
# ('Moreland', 'Coburg', 144)
# ('Moreland', 'Fitzroy North', 6)
# ('Nillumbik', None, 88)
# ('Port Phillip', None, 125)
# ('Port Phillip', 'Albert Park', 74)
# ('Port Phillip', 'Balaclava/Ripponlea', 141)
# ('Port Phillip', 'Elwood', 308)
# ('Port Phillip', 'Middle Park', 50)
# ('Port Phillip', 'Port Melbourne', 243)
# ('Port Phillip', 'Prahran/Windsor', 156)
# ('Port Phillip', 'South Melbourne', 291)
# ('Port Phillip', 'South Yarra', 133)
# ('Port Phillip', 'Southbank', 44)
# ('Port Phillip', 'St Kilda', 1082)
# ('Port Phillip', 'St Kilda East', 159)
# ('Port Phillip', 'Windsor', 2)
# ('Stonnington', None, 62)
# ('Stonnington', 'Armadale', 71)
# ('Stonnington', 'Caulfield', 3)
# ('Stonnington', 'Glen Iris', 44)
# ('Stonnington', 'Malvern', 34)
# ('Stonnington', 'Malvern East', 100)
# ('Stonnington', 'Prahran', 257)
# ('Stonnington', 'Prahran/Windsor', 4)
# ('Stonnington', 'South Yarra', 759)
# ('Stonnington', 'St Kilda', 3)
# ('Stonnington', 'St Kilda East', 2)
# ('Stonnington', 'Toorak', 117)
# ('Stonnington', 'Windsor', 165)
# ('Whitehorse', None, 574)
# ('Whitehorse', 'Balwyn', 25)
# ('Whitehorse', 'Balwyn North', 4)
# ('Whitehorse', 'Camberwell', 10)
# ('Whitehorse', 'Glen Iris', 1)
# ('Whittlesea', None, 137)
# ('Wyndham', None, 426)
# ('Yarra', None, 76)
# ('Yarra', 'Abbotsford', 254)
# ('Yarra', 'Alphington', 16)
# ('Yarra', 'Brunswick', 7)
# ('Yarra', 'Burnley', 56)
# ('Yarra', 'Carlton', 3)
# ('Yarra', 'Carlton North', 128)
# ('Yarra', 'Clifton Hill', 59)
# ('Yarra', 'Collingwood', 283)
# ('Yarra', 'East Melbourne', 8)
# ('Yarra', 'Fitzroy', 381)
# ('Yarra', 'Fitzroy North', 225)
# ('Yarra', 'Northcote', 6)
# ('Yarra', 'Richmond', 547)
# ('Yarra Ranges', None, 771)

# %% [markdown]
# #Ejercicio 1 punto 4
# Combinar los datasets de ambas tablas ingestadas utilizando el comando JOIN de SQL para obtener un resultado similar a lo realizado con Pandas en clase.

# %%
#160 Ejecutamos consulta SQL para obtener los promedios de las variables relevantes
print(airbnb_df.columns)


airbnb_agg ="""SELECT cast(zipcode as int) as int_zipcode, 
                          ROUND(AVG(price), 2) as avg_price, 
                          ROUND(AVG(monthly_price), 2) as avg_monthly_price,
                          ROUND(AVG(weekly_price), 2) as avg_weekly_price,
                          ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
                          COUNT(*)
                  FROM Airbnb GROUP BY int_zipcode"""

execute_print_sql([airbnb_agg])
# Out:
# Index(['description', 'neighborhood_overview', 'street', 'neighborhood',
#        'city', 'suburb', 'state', 'zipcode', 'latitude', 'longitude', 'price',
#        'weekly_price', 'monthly_price', 'review_scores_rating'],
#       dtype='object')
# 2022-06-07 21:37:10,649 INFO sqlalchemy.engine.Engine SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*)
#                   FROM Airbnb GROUP BY int_zipcode
# 2022-06-07 21:37:10,651 INFO sqlalchemy.engine.Engine [raw sql] ()
# SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*)
#                   FROM Airbnb GROUP BY int_zipcode
# (None, 160.96, 3352.12, 924.82, 93.17, 142)
# (0, 172.5, None, None, 96.5, 2)
# (2010, 40.0, None, None, None, 1)
# (2134, 50.0, None, None, None, 1)
# (2582, 104.0, None, None, None, 1)
# (3000, 150.47, 3407.2, 918.74, 92.78, 3368)
# (3001, 132.5, None, None, 86.5, 2)
# (3002, 200.98, 3712.71, 956.38, 94.88, 197)
# (3003, 130.21, 2629.5, 760.2, 93.9, 267)
# (3004, 158.27, 3759.93, 1061.17, 93.64, 728)
# (3006, 188.85, 4358.56, 1239.83, 94.17, 1268)
# (3008, 177.01, 3222.83, 1025.28, 93.08, 616)
# (3011, 95.6, 1624.61, 441.92, 93.25, 198)
# (3012, 112.63, 2335.0, 518.0, 94.0, 76)
# (3013, 135.61, 2966.09, 923.57, 95.4, 82)
# (3015, 132.05, 2002.33, 706.12, 95.29, 65)
# (3016, 191.09, 2119.75, 612.25, 95.02, 74)
# (3018, 85.62, 1550.5, 732.5, 94.97, 37)
# (3019, 90.47, None, 200.0, 89.54, 15)
# (3020, 69.56, 600.0, 160.0, 89.56, 45)
# (3021, 81.65, 1300.0, 350.0, 89.85, 20)
# (3023, 92.6, None, 500.0, 85.64, 35)
# (3024, 75.67, None, None, 90.0, 18)
# (3025, 113.76, None, None, 97.57, 17)
# (3027, 141.64, 1200.0, 400.0, 97.5, 39)
# (3028, 107.58, 870.0, 430.0, 90.74, 38)
# (3029, 76.15, 1692.0, 512.86, 93.87, 113)
# (3030, 115.75, 2224.6, 590.0, 94.72, 258)
# (3031, 119.91, 2184.09, 645.39, 95.13, 188)
# (3032, 111.61, 1677.92, 469.87, 94.29, 176)
# (3033, 83.64, 850.0, 306.67, 93.86, 14)
# (3034, 127.25, None, None, 94.67, 4)
# (3036, 228.2, None, None, 96.5, 5)
# (3037, 66.44, 1554.33, 426.67, 93.73, 16)
# (3038, 91.0, None, 600.0, 97.0, 8)
# (3039, 100.98, 1533.33, 392.5, 94.31, 52)
# (3040, 114.14, 3366.67, 787.5, 92.74, 56)
# (3041, 106.12, 1500.0, 350.0, 96.8, 8)
# (3042, 81.57, 1800.75, 568.2, 95.52, 35)
# (3043, 114.83, 1502.0, 700.0, 93.38, 29)
# (3044, 98.95, 1567.5, 514.2, 96.19, 40)
# (3046, 69.03, 1076.67, 351.0, 94.92, 60)
# (3047, 63.86, None, 475.0, 87.94, 21)
# (3048, 57.5, None, None, 95.33, 4)
# (3049, 92.29, None, 400.0, 95.3, 21)
# (3051, 112.23, 3152.15, 753.53, 92.88, 338)
# (3052, 91.51, 1633.13, 471.54, 92.97, 90)
# (3053, 111.77, 3205.32, 923.51, 92.61, 538)
# (3054, 121.4, 1690.89, 642.5, 94.78, 138)
# (3055, 87.83, 1725.93, 519.29, 94.18, 87)
# (3056, 94.67, 2308.98, 618.76, 94.76, 446)
# (3057, 154.43, 2789.67, 595.84, 94.19, 185)
# (3058, 103.11, 3624.17, 896.06, 94.88, 133)
# (3059, 136.41, 1612.67, 420.67, 98.0, 17)
# (3060, 49.67, None, None, 91.57, 9)
# (3063, 160.14, 7000.0, 2000.0, 96.2, 7)
# (3064, 71.4, None, 185.0, 94.41, 42)
# (3065, 153.84, 3734.65, 1087.56, 96.11, 387)
# (3066, 145.99, 3087.23, 920.08, 95.81, 297)
# (3067, 130.62, 2187.03, 605.15, 95.29, 258)
# (3068, 126.01, 2801.84, 801.32, 95.83, 308)
# (3070, 113.28, 2429.34, 585.76, 95.53, 284)
# (3071, 125.01, 2580.1, 675.8, 94.74, 114)
# (3072, 94.16, 1449.2, 525.43, 95.49, 141)
# (3073, 273.93, 1459.63, 399.89, 92.57, 68)
# (3074, 82.5, None, None, 91.25, 12)
# (3075, 142.8, 800.0, 200.0, 88.29, 10)
# (3076, 51.53, 1440.0, 395.0, 93.55, 17)
# (3078, 111.2, 2233.87, 605.0, 93.41, 74)
# (3079, 125.47, 1875.0, 514.9, 94.94, 38)
# (3081, 83.66, 937.5, 291.43, 94.0, 38)
# (3082, 76.67, None, None, 93.89, 18)
# (3083, 84.14, 2291.5, 702.5, 90.8, 87)
# (3084, 126.41, 2215.0, 1081.11, 93.64, 73)
# (3085, 93.33, 750.0, 200.0, 85.5, 6)
# (3087, 77.0, None, None, 96.5, 3)
# (3088, 68.36, 955.0, 250.0, 95.17, 11)
# (3089, 81.17, None, 350.0, 96.2, 6)
# (3093, 89.83, 1820.0, 525.0, 96.83, 6)
# (3094, 94.22, None, None, 95.33, 9)
# (3095, 112.0, 2850.0, 701.6, 98.42, 29)
# (3096, 100.0, 1500.0, 250.0, 99.0, 1)
# (3097, 147.41, 4157.0, 1098.33, 94.91, 17)
# (3099, 136.0, 2119.33, 586.25, 98.44, 10)
# (3101, 139.6, 1300.0, 609.75, 92.84, 107)
# (3102, 759.08, 5627.0, 1589.0, 89.33, 12)
# (3103, 105.26, 2111.25, 606.75, 91.31, 57)
# (3104, 97.27, 4063.0, 1118.0, 95.15, 41)
# (3105, 116.26, 2000.0, 528.0, 85.95, 23)
# (3106, 127.22, None, None, 98.0, 23)
# (3107, 228.26, 1400.0, 350.0, 90.31, 19)
# (3108, 128.83, 5125.25, 1137.5, 92.84, 141)
# (3109, 117.0, 4311.8, 1042.14, 93.53, 53)
# (3111, 151.8, 2217.0, 624.33, 89.0, 10)
# (3113, 281.94, 1976.67, 678.13, 93.32, 31)
# (3114, 270.0, None, 640.0, 97.29, 8)
# (3115, 224.14, 10060.0, 2236.67, 97.5, 7)
# (3116, 349.18, 1261.0, 390.5, 93.1, 11)
# (3121, 162.26, 3771.91, 1089.07, 95.6, 628)
# (3122, 180.57, 8158.9, 1726.42, 95.58, 184)
# (3123, 151.3, 6069.0, 1340.67, 95.8, 81)
# (3124, 138.56, 2742.57, 526.67, 96.17, 88)
# (3125, 88.15, 870.0, 383.75, 88.31, 61)
# (3126, 148.13, 2702.0, 922.0, 93.36, 23)
# (3127, 86.41, 1699.0, 444.5, 93.3, 68)
# (3128, 111.44, 1610.63, 426.38, 91.99, 214)
# (3129, 113.0, 527.0, 133.0, 91.27, 104)
# (3130, 102.58, 2147.14, 501.75, 94.02, 59)
# (3131, 112.59, 1975.0, 465.2, 93.07, 27)
# (3132, 68.61, None, None, 92.65, 38)
# (3133, 76.18, 3980.0, 660.0, 88.48, 44)
# (3134, 116.59, 1202.33, 354.67, 93.17, 56)
# (3135, 104.12, None, None, 95.27, 17)
# (3136, 84.81, 2529.67, 742.0, 96.18, 26)
# (3137, 109.78, 7000.0, 1300.0, 95.5, 9)
# (3138, 110.5, None, None, 95.15, 14)
# (3139, 247.55, 2934.67, 1882.13, 97.77, 38)
# (3140, 168.95, None, 1366.67, 95.17, 21)
# (3141, 157.91, 3417.81, 1040.4, 94.47, 881)
# (3142, 244.5, 4471.83, 1168.82, 93.91, 118)
# (3143, 192.46, 3130.5, 743.18, 95.83, 69)
# (3144, 290.84, 8634.2, 1984.37, 93.8, 45)
# (3145, 116.27, 980.0, 416.54, 92.39, 116)
# (3146, 135.83, 2940.75, 770.11, 94.98, 72)
# (3147, 82.76, None, 520.0, 96.58, 29)
# (3148, 79.5, 1660.33, 197.5, 95.57, 26)
# (3149, 119.42, 1588.5, 450.29, 94.58, 77)
# (3150, 124.03, 1901.61, 526.35, 93.09, 189)
# (3151, 97.66, 2200.0, 600.0, 94.93, 29)
# (3152, 92.31, 2126.4, 590.0, 90.58, 48)
# (3153, 91.75, 3512.0, 952.0, 96.46, 16)
# (3154, 107.14, 1350.0, 390.0, 98.2, 7)
# (3155, 95.57, 1099.5, 324.5, 86.92, 21)
# (3156, 125.28, None, None, 95.37, 29)
# (3158, 150.0, 2000.0, 795.0, 95.92, 15)
# (3159, 185.75, 4100.0, 1452.0, 94.27, 12)
# (3160, 190.0, 2450.0, 954.0, 97.38, 32)
# (3161, 127.43, 3429.82, 1242.93, 93.86, 122)
# (3162, 130.11, 4314.42, 1192.0, 95.79, 81)
# (3163, 94.21, 2047.75, 553.15, 94.62, 156)
# (3165, 113.04, 2032.8, 563.2, 93.96, 51)
# (3166, 113.14, 1536.17, 459.29, 89.13, 70)
# (3167, 107.22, None, None, 92.85, 23)
# (3168, 77.43, 1217.0, 379.31, 90.64, 152)
# (3169, 82.69, 951.5, 286.5, 95.79, 29)
# (3170, 59.45, None, None, 96.79, 22)
# (3171, 67.86, None, None, 96.92, 21)
# (3172, 79.67, 2500.0, 680.0, 96.44, 12)
# (3173, 71.61, None, 300.0, 89.64, 41)
# (3174, 49.0, 783.67, 276.25, 90.38, 32)
# (3175, 185.57, 4359.0, 1140.0, 92.13, 42)
# (3177, 161.6, None, None, None, 5)
# (3178, 81.88, None, None, 94.81, 41)
# (3179, 76.55, None, None, 93.6, 11)
# (3180, 282.5, None, None, 99.5, 10)
# (3181, 148.17, 3304.38, 868.15, 95.74, 460)
# (3182, 147.73, 3847.4, 1051.44, 95.01, 1135)
# (3183, 127.52, 2761.06, 795.53, 95.8, 326)
# (3184, 147.45, 3581.27, 1099.96, 95.6, 335)
# (3185, 154.13, 3374.9, 826.1, 96.11, 106)
# (3186, 268.3, 5467.08, 1029.46, 95.23, 124)
# (3187, 193.87, 1116.0, 376.88, 93.35, 53)
# (3188, 245.11, 4694.56, 1273.6, 97.87, 71)
# (3189, 97.0, None, None, 96.4, 13)
# (3190, 154.56, 3421.4, 832.6, 93.59, 39)
# (3191, 195.72, 4375.86, 1118.7, 98.06, 50)
# (3192, 115.07, 2336.67, 901.33, 90.53, 60)
# (3193, 215.93, 6171.33, 1546.0, 96.67, 42)
# (3194, 153.0, 1500.0, None, 94.56, 21)
# (3195, 143.04, 2539.0, 649.29, 94.47, 71)
# (3196, 120.69, 2373.0, 936.0, 95.34, 59)
# (3197, 140.37, 2333.33, 658.33, 91.74, 27)
# (3198, 110.0, 2379.3, 638.44, 95.7, 39)
# (3199, 174.96, 3041.0, 802.29, 94.77, 103)
# (3200, 40.0, None, None, 100.0, 1)
# (3201, 88.0, 2345.0, 678.0, 92.0, 5)
# (3202, 335.71, None, None, 97.0, 14)
# (3204, 114.61, 2936.0, 719.22, 94.6, 80)
# (3205, 214.85, 4125.23, 1226.02, 94.14, 300)
# (3206, 229.42, 3734.0, 1187.4, 96.36, 122)
# (3207, 200.21, 4743.96, 1480.79, 95.02, 257)
# (3335, 137.33, None, None, 93.33, 6)
# (3337, 110.81, None, None, 93.93, 26)
# (3338, 95.48, None, 550.0, 93.47, 25)
# (3427, 255.14, 5250.0, 1125.0, 98.17, 7)
# (3428, 287.25, None, None, 88.5, 4)
# (3429, 131.29, None, None, 96.42, 24)
# (3750, 43.5, None, None, 97.0, 6)
# (3752, 63.91, None, None, 99.75, 11)
# (3753, 302.0, None, None, None, 1)
# (3754, 115.16, 1650.0, 450.0, 97.73, 19)
# (3757, 245.0, None, None, 89.6, 7)
# (3759, 162.0, None, None, 97.6, 5)
# (3760, 135.2, 2000.0, 750.0, 98.0, 5)
# (3761, 180.0, None, None, 97.0, 2)
# (3765, 325.0, None, None, 98.0, 3)
# (3766, 259.27, 4166.67, 1113.33, 97.95, 22)
# (3767, 215.67, 2784.5, 814.0, 96.03, 42)
# (3770, 396.17, 3200.0, 1050.0, 98.23, 24)
# (3775, 337.69, 2800.0, 733.17, 96.58, 45)
# (3777, 271.26, 3802.19, 1278.51, 96.44, 187)
# (3778, 163.0, None, None, 100.0, 1)
# (3781, 195.0, 3000.0, 903.75, 97.15, 13)
# (3782, 188.59, 2975.0, 804.8, 97.0, 46)
# (3783, 177.73, None, 1047.5, 96.6, 15)
# (3785, 251.0, None, None, 100.0, 1)
# (3786, 345.36, 2688.0, 762.0, 97.18, 11)
# (3787, 253.04, 3150.0, 1088.0, 97.5, 27)
# (3788, 249.37, 5441.5, 1547.5, 97.42, 89)
# (3789, 362.75, 4550.0, 1450.0, 92.86, 8)
# (3791, 221.3, None, None, 98.56, 10)
# (3792, 282.81, None, 631.0, 98.57, 16)
# (3793, 126.88, None, None, 97.75, 8)
# (3795, 149.5, None, None, 99.0, 2)
# (3796, 154.57, 2900.0, 950.0, 96.0, 7)
# (3797, 265.72, 4000.0, 1373.33, 97.18, 18)
# (3799, 196.93, 2194.33, 992.67, 96.79, 89)
# (3802, 63.27, None, 380.0, 80.0, 11)
# (3803, 140.17, None, None, 92.67, 6)
# (3804, 193.83, 1650.0, 450.0, 99.0, 6)
# (3805, 225.24, 2178.67, 622.0, 94.69, 34)
# (3806, 488.27, None, 540.0, 94.62, 33)
# (3807, 85.75, 2714.0, 709.5, 96.67, 4)
# (3808, 278.5, 7500.0, 1800.0, 96.67, 4)
# (3809, 76.21, 1008.0, 286.0, 94.67, 14)
# (3810, 94.95, 3800.0, 723.33, 95.94, 22)
# (3812, 262.0, None, None, 99.0, 2)
# (3814, 180.0, None, None, 90.0, 3)
# (3815, 315.29, 2000.0, 1000.0, 98.33, 7)
# (3910, 118.0, None, 250.0, 96.83, 8)
# (3911, 334.6, 6350.0, 1340.0, 88.88, 10)
# (3912, 89.0, None, None, 99.0, 1)
# (3930, 114.5, None, None, 99.0, 2)
# (3975, 99.5, 3000.0, 850.0, 97.0, 6)
# (3976, 55.0, None, None, 99.0, 2)
# (3977, 92.96, 1025.0, 422.0, 94.13, 45)
# (3978, 177.0, 7770.0, 950.67, 95.4, 7)
# (3980, 86.4, None, None, 97.0, 5)
# (3981, 130.0, None, None, 98.0, 1)
# (4068, 37.0, None, None, None, 1)
# (5203, 212.0, None, None, 100.0, 1)
# (5791, 299.0, None, None, None, 1)
# (6791, 220.0, None, None, 100.0, 1)
# (7266, 220.0, None, None, None, 1)
# (7367, 230.0, None, None, None, 1)
# (8938, 296.0, None, None, None, 1)
# (9004, 226.0, None, None, None, 1)
# (9540, 245.0, None, None, None, 1)
# (30122, 75.0, 2281.0, 525.0, 100.0, 1)

# %%
#170 Join entre Melb y airbnb[interesting_cols]

sales_airbnb_join ="""
                  WITH airbnb_agg as 
                  (SELECT cast(zipcode as int) as int_zipcode, 
                          ROUND(AVG(price), 2) as avg_price, 
                          ROUND(AVG(monthly_price), 2) as avg_monthly_price,
                          ROUND(AVG(weekly_price), 2) as avg_weekly_price,
                          ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
                          COUNT(*) as zipcode_count
                  FROM Airbnb GROUP BY int_zipcode)

                  SELECT  m.*, 
                          avg_price,
                          avg_monthly_price,
                          avg_weekly_price,
                          avg_review_scores_rating,
                          zipcode_count
                  FROM Melbourne m 
                  left join airbnb_agg a on m.Postcode == a.int_zipcode"""

execute_print_sql([sales_airbnb_join])
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# (7392, 'South Kingsville', '56b Vernon St', 2, 't', 611000.0, 'SP', 'Williams', '28/08/2016', 9.1, 3015.0, 2.0, 1.0, 1.0, 228.0, 100.0, 2000.0, 'Hobsons Bay', -37.8317, 144.8713, 'Western Metropolitan', 984.0, 132.05, 2002.33, 706.12, 95.29, 65)
# (7393, 'Strathmore Heights', '4 Boeing Rd', 4, 'h', 1260000.0, 'S', 'Nelson', '10/09/2016', 12.5, 3041.0, 4.0, 2.0, 2.0, 697.0, 277.0, 2012.0, 'Moonee Valley', -37.7141, 144.8995, 'Western Metropolitan', 389.0, 106.12, 1500.0, 350.0, 96.8, 8)
# (7394, 'Strathmore Heights', '12 Boeing Rd', 4, 'h', 931999.0, 'S', 'Nelson', '12/11/2016', 12.5, 3041.0, 4.0, 3.0, 2.0, 528.0, 192.0, 1966.0, 'Moonee Valley', -37.7137, 144.8987, 'Western Metropolitan', 389.0, 106.12, 1500.0, 350.0, 96.8, 8)
# (7395, 'Strathmore Heights', '347 Mascoma St', 4, 'h', 800000.0, 'S', 'Considine', '18/06/2016', 12.5, 3041.0, 3.0, 2.0, 4.0, 556.0, None, None, 'Moonee Valley', -37.715, 144.8966, 'Western Metropolitan', 389.0, 106.12, 1500.0, 350.0, 96.8, 8)
# (7396, 'Strathmore Heights', '5 Lockheed St', 4, 'h', 950000.0, 'S', 'Nelson', '22/05/2016', 12.5, 3041.0, 4.0, 3.0, 2.0, 541.0, None, None, 'Moonee Valley', -37.7156, 144.8975, 'Western Metropolitan', 389.0, 106.12, 1500.0, 350.0, 96.8, 8)
# (7397, 'Strathmore Heights', '14 Elysee Ct', 4, 'h', 780000.0, 'VB', 'Brad', '22/08/2016', 12.5, 3041.0, 4.0, 2.0, 2.0, 539.0, None, None, 'Moonee Valley', -37.7115, 144.8966, 'Western Metropolitan', 389.0, 106.12, 1500.0, 350.0, 96.8, 8)
# (7398, 'Travancore', '2/9 Buckland St', 2, 'u', 503000.0, 'S', 'Nelson', '10/12/2016', 5.3, 3032.0, 2.0, 1.0, 1.0, 0.0, None, 1960.0, 'Moonee Valley', -37.7822, 144.9342, 'Western Metropolitan', 1052.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7399, 'Travancore', '61 Mooltan St', 3, 'h', 1257000.0, 'S', 'Jellis', '13/08/2016', 5.3, 3032.0, 3.0, 2.0, 1.0, 337.0, 153.0, 1930.0, 'Moonee Valley', -37.7813, 144.9371, 'Western Metropolitan', 1052.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7400, 'Travancore', '110 Baroda St', 4, 'h', 1562000.0, 'SP', 'Nelson', '15/10/2016', 5.3, 3032.0, 4.0, 2.0, 1.0, 621.0, 192.0, 1900.0, 'Moonee Valley', -37.7778, 144.9346, 'Western Metropolitan', 1052.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7401, 'Travancore', '47 Mooltan St', 2, 'h', 1100000.0, 'SP', 'Nelson', '18/06/2016', 5.3, 3032.0, 2.0, 1.0, 1.0, 321.0, None, None, 'Moonee Valley', -37.7818, 144.9374, 'Western Metropolitan', 1052.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7402, 'Travancore', '53 Mangalore St', 4, 'h', 1740000.0, 'VB', 'Nelson', '22/05/2016', 5.3, 3032.0, 3.0, 3.0, 2.0, 650.0, 242.0, 1925.0, 'Moonee Valley', -37.7796, 144.935, 'Western Metropolitan', 1052.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7403, 'Travancore', '145/38 Mt Alexander Rd', 2, 'u', 315000.0, 'SP', 'Ray', '28/05/2016', 5.3, 3032.0, 2.0, 1.0, 1.0, 0.0, 51.0, 2012.0, 'Moonee Valley', -37.7847, 144.9383, 'Western Metropolitan', 1052.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7404, 'Caulfield East', '5 Grange Rd', 3, 'h', 1650000.0, 'PI', 'Woodards', '6/08/2016', 9.3, 3145.0, 20.0, 1.0, 2.0, 875.0, None, None, 'Glen Eira', -37.8815, 145.0491, 'Southern Metropolitan', 608.0, 116.27, 980.0, 416.54, 92.39, 116)
# (7405, 'Caulfield East', '4 Lord St', 3, 'h', 1380000.0, 'S', 'Bayside', '8/10/2016', 9.3, 3145.0, 3.0, 1.0, 2.0, 658.0, None, None, 'Glen Eira', -37.885, 145.0466, 'Southern Metropolitan', 608.0, 116.27, 980.0, 416.54, 92.39, 116)
# (7406, 'Caulfield East', '9 Lord St', 2, 'h', 620000.0, 'SP', 'Woodards', '10/12/2016', 9.3, 3145.0, 2.0, 1.0, 2.0, 0.0, None, None, 'Glen Eira', -37.8852, 145.0462, 'Southern Metropolitan', 608.0, 116.27, 980.0, 416.54, 92.39, 116)
# (7407, 'Caulfield East', '75 Grange Rd', 5, 'h', 1335000.0, 'S', 'Gary', '16/07/2016', 9.3, 3145.0, 5.0, 2.0, 1.0, 521.0, 208.0, 1915.0, 'Glen Eira', -37.8868, 145.0462, 'Southern Metropolitan', 608.0, 116.27, 980.0, 416.54, 92.39, 116)
# (7408, 'Caulfield East', '17 Clifton St', 2, 'h', 1000000.0, 'S', 'hockingstuart', '25/02/2017', 9.3, 3145.0, 2.0, 1.0, 1.0, 472.0, None, 1960.0, 'Glen Eira', -37.884, 145.0447, 'Southern Metropolitan', 608.0, 116.27, 980.0, 416.54, 92.39, 116)
# (7409, 'Seaholme', '41 Simmons Dr', 3, 'h', 860000.0, 'PI', 'RT', '6/08/2016', 12.7, 3018.0, 3.0, 2.0, 2.0, 537.0, None, None, 'Hobsons Bay', -37.8628, 144.8468, 'Western Metropolitan', 852.0, 85.62, 1550.5, 732.5, 94.97, 37)
# (7410, 'Seaholme', '13 Sussex St', 5, 'h', 1415000.0, 'S', 'Greg', '17/09/2016', 12.7, 3018.0, 5.0, 3.0, 6.0, 705.0, 313.0, 2005.0, 'Hobsons Bay', -37.864, 144.8437, 'Western Metropolitan', 852.0, 85.62, 1550.5, 732.5, 94.97, 37)
# (7411, 'Seaholme', '10 Wattle Gr', 5, 'h', 2000000.0, 'PI', 'RT', '25/02/2017', 12.7, 3018.0, 4.0, 3.0, 4.0, 697.0, None, 2005.0, 'Hobsons Bay', -37.8664, 144.8416, 'Western Metropolitan', 852.0, 85.62, 1550.5, 732.5, 94.97, 37)
# (7412, 'Keilor Park', '31 Swan St', 3, 'h', 720000.0, 'S', 'Nelson', '8/10/2016', 14.5, 3042.0, 3.0, 1.0, 1.0, 696.0, 132.0, 1975.0, 'Brimbank', -37.725, 144.8586, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7413, 'Keilor Park', '5/8 Swan St', 2, 't', 380000.0, 'S', 'Nelson', '10/09/2016', 14.5, 3042.0, 2.0, 1.0, 1.0, 161.0, 100.0, 2010.0, 'Brimbank', -37.7251, 144.8621, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7414, 'Keilor Park', '60 Erebus St', 4, 'h', 843000.0, 'S', 'Barry', '11/02/2017', 14.5, 3042.0, 4.0, 2.0, 1.0, 697.0, None, None, 'Brimbank', -37.7216, 144.8605, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7415, 'Keilor Park', '2/90 Victory St', 3, 'u', 501000.0, 'S', 'Barry', '12/11/2016', 14.5, 3042.0, 3.0, 1.0, 1.0, 255.0, 132.0, 1991.0, 'Brimbank', -37.7243, 144.8533, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7416, 'Keilor Park', '50 Collinson St', 4, 'h', 820500.0, 'S', 'YPA', '18/03/2017', 14.5, 3042.0, 4.0, 2.0, 7.0, 754.0, None, None, 'Brimbank', -37.7221, 144.8578, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7417, 'Keilor Park', '47 Victory St', 3, 'h', 722000.0, 'SP', 'Brad', '18/06/2016', 14.5, 3042.0, 3.0, 1.0, 1.0, 695.0, 141.0, 1970.0, 'Brimbank', -37.7259, 144.8579, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7418, 'Keilor Park', '44 Erebus St', 4, 't', 746000.0, 'S', 'Barry', '22/05/2016', 14.5, 3042.0, 4.0, 3.0, 1.0, 308.0, 174.0, 1970.0, 'Brimbank', -37.7231, 144.8602, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7419, 'Keilor Park', '2a Flinders St', 3, 'h', 685000.0, 'S', 'Nelson', '26/07/2016', 14.5, 3042.0, 3.0, 2.0, 2.0, 260.0, None, None, 'Brimbank', -37.7226, 144.8569, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7420, 'Keilor Park', '2/125 Fosters Rd', 3, 'u', 455000.0, 'S', 'Nelson', '27/06/2016', 14.5, 3042.0, 3.0, 1.0, 1.0, 166.0, 136.0, 1999.0, 'Brimbank', -37.7169, 144.8582, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7421, 'Keilor Park', '3/550 Fullarton Rd', 4, 't', 600000.0, 'S', 'Barry', '27/11/2016', 14.5, 3042.0, 4.0, 2.0, 1.0, 231.0, 146.0, 2013.0, 'Brimbank', -37.7263, 144.8584, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7422, 'Keilor Park', '18 William St', 3, 'h', 575000.0, 'S', 'Nelson', '27/11/2016', 14.5, 3042.0, 3.0, 1.0, 1.0, 338.0, 107.0, 1960.0, 'Brimbank', -37.7212, 144.8545, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7423, 'Keilor Park', '35 Spence St', 3, 'h', 566000.0, 'S', 'Nelson', '28/05/2016', 14.5, 3042.0, 3.0, 2.0, 2.0, 554.0, 129.0, 1980.0, 'Brimbank', -37.7212, 144.8598, 'Western Metropolitan', 1119.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (7424, 'Gardenvale', '66A Gardenvale Rd', 3, 'h', 1250000.0, 'PI', 'Nick', '11/02/2017', 9.8, 3185.0, 3.0, 2.0, 2.0, 236.0, 193.0, 2004.0, 'Glen Eira', -37.8982, 145.0121, 'Southern Metropolitan', 534.0, 154.13, 3374.9, 826.1, 96.11, 106)
# (7425, 'Gardenvale', '2/32 Gardenia Rd', 2, 'u', 393000.0, 'SP', 'Biggin', '14/05/2016', 9.8, 3185.0, 2.0, 1.0, 1.0, 0.0, 65.0, 1970.0, 'Glen Eira', -37.8971, 145.0093, 'Southern Metropolitan', 534.0, 154.13, 3374.9, 826.1, 96.11, 106)
# (7426, 'Gardenvale', '7/32 Gardenia Rd', 2, 'u', 440000.0, 'S', 'Biggin', '18/06/2016', 9.8, 3185.0, 2.0, 1.0, 1.0, 0.0, 75.0, None, 'Glen Eira', -37.8971, 145.0093, 'Southern Metropolitan', 534.0, 154.13, 3374.9, 826.1, 96.11, 106)
# (7427, 'Gardenvale', '1/18 Magnolia Rd', 2, 'u', 595000.0, 'S', 'Biggin', '19/11/2016', 9.8, 3185.0, 2.0, 1.0, 1.0, 0.0, 75.0, 1960.0, 'Glen Eira', -37.8994, 145.0101, 'Southern Metropolitan', 534.0, 154.13, 3374.9, 826.1, 96.11, 106)
# (7428, 'Gardenvale', '25 Magnolia Rd', 4, 'h', 2200000.0, 'S', 'hockingstuart', '28/08/2016', 9.8, 3185.0, 4.0, 3.0, 3.0, 474.0, 230.0, 2010.0, 'Glen Eira', -37.8988, 145.0098, 'Southern Metropolitan', 534.0, 154.13, 3374.9, 826.1, 96.11, 106)
# (7429, 'Princes Hill', '76 Arnold St', 3, 'h', 1700000.0, 'VB', 'Collins', '27/11/2016', 3.7, 3054.0, 3.0, 1.0, 2.0, 341.0, None, None, 'Yarra', -37.7832, 144.9655, 'Northern Metropolitan', 1008.0, 121.4, 1690.89, 642.5, 94.78, 138)
# (7430, 'Princes Hill', '77 McIlwraith St', 4, 'h', 1908000.0, 'S', 'Nelson', '28/05/2016', 3.7, 3054.0, 4.0, 2.0, 1.0, 256.0, 156.0, 1890.0, 'Yarra', -37.7833, 144.9681, 'Northern Metropolitan', 1008.0, 121.4, 1690.89, 642.5, 94.78, 138)
# (7431, 'Aberfeldie', '32 Fawkner St', 4, 'h', 1330000.0, 'S', 'Nelson', '6/05/2017', 9.1, 3040.0, 4.0, 2.0, 2.0, 273.0, None, None, 'Moonee Valley', -37.7574, 144.8959, 'Western Metropolitan', 1543.0, 114.14, 3366.67, 787.5, 92.74, 56)
# (7432, 'Aberfeldie', '2/65 Clifton St', 3, 'h', 1300000.0, 'S', 'Nelson', '8/04/2017', 9.1, 3040.0, 3.0, 3.0, 2.0, 240.0, 240.0, 2013.0, 'Moonee Valley', -37.762, 144.8916, 'Western Metropolitan', 1543.0, 114.14, 3366.67, 787.5, 92.74, 56)
# (7433, 'Aberfeldie', '3/4 Combermere St', 2, 'h', 470000.0, 'S', 'Barry', '8/04/2017', 9.1, 3040.0, 2.0, 1.0, 1.0, 70.0, 72.3, 1980.0, 'Moonee Valley', -37.7564, 144.9043, 'Western Metropolitan', 1543.0, 114.14, 3366.67, 787.5, 92.74, 56)
# (7434, 'Aberfeldie', '2 Derry St', 4, 'h', 1740000.0, 'PI', 'Nelson', '29/04/2017', 9.1, 3040.0, 4.0, 2.0, 2.0, 746.0, 161.0, 1950.0, 'Moonee Valley', -37.7595, 144.8993, 'Western Metropolitan', 1543.0, 114.14, 3366.67, 787.5, 92.74, 56)
# (7435, 'Albert Park', '4 Ashworth St', 3, 'h', 1700000.0, 'VB', 'Greg', '6/05/2017', 3.3, 3206.0, 3.0, 1.0, 1.0, 178.0, 116.0, 1910.0, 'Port Phillip', -37.8473, 144.9495, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7436, 'Albert Park', '13/123 Beaconsfield Pde', 1, 'u', 1100000.0, 'PI', 'Nelson', '8/04/2017', 3.3, 3206.0, 1.0, 1.0, 1.0, 0.0, 64.0, 1888.0, 'Port Phillip', -37.8487, 144.9511, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7437, 'Albert Park', '102 Graham St', 3, 'h', 2155000.0, 'S', 'RT', '8/04/2017', 3.3, 3206.0, 3.0, 2.0, 0.0, 130.0, None, None, 'Port Phillip', -37.8453, 144.94899999999996, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7438, 'Albert Park', '374 Montague St', 3, 'h', 2115000.0, 'PI', 'Marshall', '8/04/2017', 3.3, 3206.0, 3.0, 2.0, 0.0, 140.0, None, None, 'Port Phillip', -37.8426, 144.9563, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7439, 'Albert Park', '75 Richardson St', 2, 'h', 2810000.0, 'S', 'Greg', '8/04/2017', 3.3, 3206.0, 2.0, 1.0, 1.0, 263.0, None, None, 'Port Phillip', -37.8441, 144.9522, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7440, 'Albert Park', '21 Finlay St', 2, 'h', 2130000.0, 'S', 'Marshall', '13/05/2017', 3.3, 3206.0, 2.0, 1.0, 1.0, 236.0, None, None, 'Port Phillip', -37.8436, 144.9558, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7441, 'Albert Park', '28 Hambleton St', 4, 'h', 2950000.0, 'S', 'Greg', '20/05/2017', 3.3, 3206.0, 4.0, 1.0, 0.0, 306.0, None, None, 'Port Phillip', -37.8459, 144.9574, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7442, 'Albert Park', '91 Page St', 3, 'h', 2150000.0, 'S', 'Marshall', '20/05/2017', 3.3, 3206.0, 3.0, 1.0, 1.0, 163.0, 85.0, 1890.0, 'Port Phillip', -37.8473, 144.955, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7443, 'Albert Park', '6 Gray La', 3, 'h', 2035000.0, 'SP', 'White', '29/04/2017', 3.3, 3206.0, 3.0, 1.0, 1.0, 185.0, None, None, 'Port Phillip', -37.8435, 144.9538, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7444, 'Albert Park', '2A Mills St', 2, 't', 1500000.0, 'S', 'Marshall', '29/04/2017', 3.3, 3206.0, 2.0, 1.0, 1.0, 115.0, None, None, 'Port Phillip', -37.8441, 144.9598, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7445, 'Albert Park', '46 Withers St', 2, 'h', 1190000.0, 'S', 'RT', '29/04/2017', 3.3, 3206.0, 2.0, 1.0, 0.0, 111.0, 70.0, 1915.0, 'Port Phillip', -37.8445, 144.9489, 'Southern Metropolitan', 3280.0, 229.42, 3734.0, 1187.4, 96.36, 122)
# (7446, 'Alphington', '10/90 Yarralea St', 1, 'u', 320000.0, 'S', 'Miles', '6/05/2017', 6.4, 3078.0, 1.0, 1.0, 1.0, 915.0, None, None, 'Darebin', -37.7793, 145.0327, 'Northern Metropolitan', 2211.0, 111.2, 2233.87, 605.0, 93.41, 74)
# (7447, 'Alphington', '57 Yarralea St', 3, 't', 1285000.0, 'PI', 'Nelson', '13/05/2017', 6.4, 3078.0, 3.0, 2.0, 2.0, 528.0, None, 1967.0, 'Yarra', -37.7817, 145.0319, 'Northern Metropolitan', 2211.0, 111.2, 2233.87, 605.0, 93.41, 74)
# (7448, 'Alphington', '55 Bennett St', 4, 'h', 1975000.0, 'S', 'Nelson', '20/05/2017', 6.4, 3078.0, 4.0, 2.0, 2.0, 600.0, None, None, 'Darebin', -37.771, 145.0318, 'Northern Metropolitan', 2211.0, 111.2, 2233.87, 605.0, 93.41, 74)
# (7449, 'Alphington', '3/34 Grange Rd', 1, 'u', 316000.0, 'S', 'Fletchers', '20/05/2017', 6.4, 3078.0, 1.0, 1.0, 1.0, 0.0, None, None, 'Darebin', -37.7786, 145.0253, 'Northern Metropolitan', 2211.0, 111.2, 2233.87, 605.0, 93.41, 74)
# (7450, 'Altona North', '269 Blackshaws Rd', 3, 'h', 916000.0, 'SP', 'Hunter', '20/05/2017', 11.1, 3025.0, 3.0, 1.0, 2.0, 606.0, 109.0, 1970.0, 'Hobsons Bay', -37.8326, 144.8594, 'Western Metropolitan', 5132.0, 113.76, None, None, 97.57, 17)
# (7451, 'Altona North', '68 Chambers Rd', 3, 'h', 750000.0, 'S', 'RT', '20/05/2017', 11.1, 3025.0, 3.0, 1.0, 2.0, 534.0, None, None, 'Hobsons Bay', -37.8367, 144.8425, 'Western Metropolitan', 5132.0, 113.76, None, None, 97.57, 17)
# (7452, 'Altona North', '23 Rymill Ct', 3, 'h', 910000.0, 'S', 'hockingstuart', '29/04/2017', 11.1, 3025.0, 3.0, 1.0, 3.0, 535.0, 132.0, 1970.0, 'Hobsons Bay', -37.8322, 144.8399, 'Western Metropolitan', 5132.0, 113.76, None, None, 97.57, 17)
# (7453, 'Armadale', '22 Baldwin St', 2, 'h', 1859000.0, 'S', 'Marshall', '6/05/2017', 6.3, 3143.0, 2.0, 2.0, 3.0, 311.0, None, None, 'Stonnington', -37.8545, 145.0219, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7454, 'Armadale', '5/29 Mercer Rd', 2, 't', 1200000.0, 'S', 'RT', '6/05/2017', 6.3, 3143.0, 2.0, 2.0, 1.0, 189.0, None, None, 'Stonnington', -37.8532, 145.0259, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7455, 'Armadale', '8/15 Egerton Rd', 2, 'u', 480000.0, 'VB', 'hockingstuart', '8/04/2017', 6.3, 3143.0, 2.0, 1.0, 1.0, 0.0, 66.23, 1960.0, 'Stonnington', -37.8624, 145.0223, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7456, 'Armadale', '4/48 New St', 3, 'u', 1635000.0, 'S', 'Jellis', '20/05/2017', 6.3, 3143.0, 3.0, 2.0, 2.0, 1803.0, None, 2011.0, 'Stonnington', -37.8544, 145.0164, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7457, 'Armadale', '18 Rose St', 2, 'h', 1705000.0, 'S', 'Marshall', '20/05/2017', 6.3, 3143.0, 2.0, 2.0, 0.0, 195.0, None, None, 'Stonnington', -37.851, 145.0156, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7458, 'Armadale', '4/10 St Georges Rd', 3, 't', 1005000.0, 'S', 'Kay', '22/04/2017', 6.3, 3143.0, 3.0, 2.0, 2.0, 0.0, None, None, 'Stonnington', -37.8606, 145.0209, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7459, 'Armadale', '1/5 The Terrace', 2, 'u', 852000.0, 'S', 'Woodards', '22/04/2017', 6.3, 3143.0, 2.0, 1.0, 1.0, 869.0, 74.0, 1980.0, 'Stonnington', -37.8603, 145.0224, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7460, 'Armadale', '8/16 Wattletree Rd', 2, 'u', 690000.0, 'S', 'Jellis', '22/04/2017', 6.3, 3143.0, 2.0, 1.0, 2.0, 0.0, None, None, 'Stonnington', -37.8611, 145.0174, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7461, 'Armadale', '1/25 Mercer Rd', 3, 'u', 2120000.0, 'S', 'Jellis', '29/04/2017', 6.3, 3143.0, 3.0, 2.0, 3.0, 395.0, None, None, 'Stonnington', -37.8536, 145.0263, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7462, 'Armadale', '6/581 Orrong Rd', 1, 'u', 405000.0, 'S', 'Marshall', '29/04/2017', 6.3, 3143.0, 1.0, 1.0, 0.0, 0.0, 48.0, 1966.0, 'Stonnington', -37.8531, 145.0115, 'Southern Metropolitan', 4836.0, 192.46, 3130.5, 743.18, 95.83, 69)
# (7463, 'Ascot Vale', '8 Anderson St', 5, 'h', 2100000.0, 'S', 'Nelson', '6/05/2017', 5.9, 3032.0, 5.0, 3.0, 3.0, 468.0, 274.0, 1925.0, 'Moonee Valley', -37.7822, 144.9065, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7464, 'Ascot Vale', '6 Munro St', 3, 'h', 1435000.0, 'S', 'Nelson', '8/04/2017', 5.9, 3032.0, 3.0, 1.0, 1.0, 450.0, 155.0, 1920.0, 'Moonee Valley', -37.7756, 144.9148, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7465, 'Ascot Vale', '72 Bloomfield Rd', 2, 'h', 1020000.0, 'PI', 'Nelson', '13/05/2017', 5.9, 3032.0, 2.0, 1.0, 1.0, 226.0, 98.0, 1920.0, 'Moonee Valley', -37.7761, 144.9165, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7466, 'Ascot Vale', '3 Dalgety Dr', 3, 'h', 1041000.0, 'S', 'Nelson', '13/05/2017', 5.9, 3032.0, 3.0, 2.0, 2.0, 209.0, None, 2009.0, 'Moonee Valley', -37.7774, 144.904, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7467, 'Ascot Vale', '4/225 Maribyrnong Rd', 2, 't', 565000.0, 'S', 'Woodards', '13/05/2017', 5.9, 3032.0, 2.0, 2.0, 1.0, 103.0, None, None, 'Moonee Valley', -37.7715, 144.9088, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7468, 'Ascot Vale', '75 Maribyrnong Rd', 6, 'h', 2250000.0, 'PI', 'Jellis', '13/05/2017', 5.9, 3032.0, 6.0, 3.0, 2.0, 1012.0, 435.0, 1887.0, 'Moonee Valley', -37.7721, 144.9184, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7469, 'Ascot Vale', '5/9 Sandown Rd', 4, 't', 900000.0, 'SP', 'Alexkarbon', '13/05/2017', 5.9, 3032.0, 4.0, 3.0, 2.0, 0.0, 159.0, 2011.0, 'Moonee Valley', -37.7831, 144.9209, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7470, 'Ascot Vale', '7 Elliott St', 3, 'h', 1490000.0, 'S', 'Nelson', '20/05/2017', 5.9, 3032.0, 3.0, 2.0, 1.0, 542.0, None, None, 'Moonee Valley', -37.781, 144.9095, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7471, 'Ascot Vale', '17 Monash St', 3, 'h', 1230000.0, 'PI', 'Nelson', '20/05/2017', 5.9, 3032.0, 3.0, 1.0, 2.0, 538.0, None, None, 'Moonee Valley', -37.7808, 144.9083, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7472, 'Ascot Vale', '136 The Parade', 2, 'h', 1050000.0, 'S', 'Brad', '20/05/2017', 5.9, 3032.0, 2.0, 1.0, 0.0, 341.0, None, None, 'Moonee Valley', -37.7721, 144.9113, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7473, 'Ascot Vale', '3 Federation St', 2, 'h', 1005000.0, 'S', 'Brad', '29/04/2017', 5.9, 3032.0, 2.0, 1.0, 1.0, 202.0, None, None, 'Moonee Valley', -37.7737, 144.9166, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7474, 'Ascot Vale', '40 Kent St', 4, 'h', 1316500.0, 'S', 'Alexkarbon', '29/04/2017', 5.9, 3032.0, 4.0, 3.0, 2.0, 230.0, None, None, 'Moonee Valley', -37.7804, 144.9284, 'Western Metropolitan', 6567.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (7475, 'Ashwood', '5 Harcourt St', 2, 'h', 1495000.0, 'S', 'Barry', '8/04/2017', 12.2, 3147.0, 2.0, 1.0, 2.0, 803.0, 95.0, 1950.0, 'Monash', -37.8683, 145.1064, 'Southern Metropolitan', 2894.0, 82.76, None, 520.0, 96.58, 29)
# (7476, 'Ashwood', '217 Huntingdale Rd', 4, 'h', 1126000.0, 'S', 'Harcourts', '8/04/2017', 12.2, 3147.0, 4.0, 1.0, 1.0, 656.0, None, None, 'Monash', -37.8696, 145.1111, 'Southern Metropolitan', 2894.0, 82.76, None, 520.0, 96.58, 29)
# (7477, 'Ashwood', '1/7 Queens Pde', 2, 'u', 822000.0, 'S', 'Marshall', '8/04/2017', 12.2, 3147.0, 2.0, 1.0, 1.0, 78.0, 59.0, 1970.0, 'Monash', -37.8677, 145.0981, 'Southern Metropolitan', 2894.0, 82.76, None, 520.0, 96.58, 29)
# (7478, 'Ashwood', '3/5 Yunki Ct', 2, 't', 770000.0, 'SP', 'Buxton', '8/04/2017', 12.2, 3147.0, 2.0, 1.0, 2.0, 162.0, None, 2010.0, 'Monash', -37.871, 145.0994, 'Southern Metropolitan', 2894.0, 82.76, None, 520.0, 96.58, 29)
# (7479, 'Ashwood', '2/5 Parkhill Dr', 3, 'u', 890000.0, 'S', 'Jellis', '20/05/2017', 12.2, 3147.0, 3.0, 2.0, 2.0, 235.0, 130.0, 2006.0, 'Monash', -37.8625, 145.1083, 'Southern Metropolitan', 2894.0, 82.76, None, 520.0, 96.58, 29)
# (7480, 'Avondale Heights', '33a Deutscher St', 3, 'u', 765000.0, 'S', 'Moonee', '6/05/2017', 10.5, 3034.0, 3.0, 2.0, 1.0, 292.0, 150.0, 2008.0, 'Moonee Valley', -37.7593, 144.8561, 'Western Metropolitan', 4502.0, 127.25, None, None, 94.67, 4)
# (7481, 'Avondale Heights', '39 Ridge Dr', 3, 'h', 881000.0, 'S', 'Nelson', '8/04/2017', 10.5, 3034.0, 3.0, 1.0, 2.0, 615.0, None, None, 'Moonee Valley', -37.7532, 144.8548, 'Western Metropolitan', 4502.0, 127.25, None, None, 94.67, 4)
# (7482, 'Avondale Heights', '47 Wood St', 4, 'h', 850000.0, 'SP', 'Moonee', '8/04/2017', 10.5, 3034.0, 4.0, 1.0, 2.0, 697.0, None, None, 'Moonee Valley', -37.7678, 144.8568, 'Western Metropolitan', 4502.0, 127.25, None, None, 94.67, 4)
# (7483, 'Avondale Heights', '16 Cortina Pl', 4, 'h', 1300000.0, 'SP', 'Nelson', '20/05/2017', 10.5, 3034.0, 4.0, 3.0, 2.0, 656.0, 322.0, 1990.0, 'Moonee Valley', -37.7522, 144.8659, 'Western Metropolitan', 4502.0, 127.25, None, None, 94.67, 4)
# (7484, 'Avondale Heights', '4 Camille Ct', 5, 'h', 1250000.0, 'SP', 'Moonee', '22/04/2017', 10.5, 3034.0, 5.0, 2.0, 2.0, 889.0, None, None, 'Moonee Valley', -37.7565, 144.8652, 'Western Metropolitan', 4502.0, 127.25, None, None, 94.67, 4)
# (7485, 'Avondale Heights', '53 Doyle St', 3, 'h', 760000.0, 'SP', 'Moonee', '22/04/2017', 10.5, 3034.0, 3.0, 1.0, 1.0, 585.0, 99.0, 1960.0, 'Moonee Valley', -37.7574, 144.8574, 'Western Metropolitan', 4502.0, 127.25, None, None, 94.67, 4)
# (7486, 'Avondale Heights', '30 Lorgrove Ct', 4, 'h', 1600000.0, 'VB', 'Nelson', '29/04/2017', 10.5, 3034.0, 4.0, 3.0, 3.0, 857.0, None, None, 'Moonee Valley', -37.7619, 144.866, 'Western Metropolitan', 4502.0, 127.25, None, None, 94.67, 4)
# (7487, 'Balwyn North', '25 Rookwood St', 2, 'h', 1900000.0, 'S', 'Noel', '8/04/2017', 9.2, 3104.0, 2.0, 1.0, 2.0, 667.0, 130.0, 1955.0, 'Boroondara', -37.7926, 145.0842, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7488, 'Balwyn North', '24 Yeneda St', 3, 'h', 1922000.0, 'S', 'hockingstuart', '8/04/2017', 9.2, 3104.0, 3.0, 1.0, 1.0, 696.0, None, None, 'Boroondara', -37.8016, 145.1013, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7489, 'Balwyn North', '103 Longview Rd', 4, 'h', 2000000.0, 'PI', 'RT', '13/05/2017', 9.2, 3104.0, 4.0, 2.0, 2.0, 627.0, None, None, 'Boroondara', -37.7848, 145.0788, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7490, 'Balwyn North', '2/21 Pavo St', 3, 'u', 700000.0, 'S', 'Marshall', '13/05/2017', 9.2, 3104.0, 3.0, 1.0, 1.0, 350.0, 120.0, 1950.0, 'Boroondara', -37.7862, 145.0739, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7491, 'Balwyn North', '35 Sylvander St', 4, 'h', 1890000.0, 'S', 'Jellis', '13/05/2017', 9.2, 3104.0, 4.0, 3.0, 2.0, 636.0, 227.0, 1960.0, 'Boroondara', -37.789, 145.0938, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7492, 'Balwyn North', '18 Woodville St', 4, 'h', 1630000.0, 'S', 'Jellis', '13/05/2017', 9.2, 3104.0, 4.0, 2.0, 1.0, 677.0, None, None, 'Boroondara', -37.7897, 145.0922, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7493, 'Balwyn North', '2/87 Tannock St', 2, 'u', 800000.0, 'PI', 'hockingstuart', '20/05/2017', 9.2, 3104.0, 2.0, 2.0, 1.0, 196.0, None, 1994.0, 'Boroondara', -37.785, 145.0961, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7494, 'Balwyn North', '215 Doncaster Rd', 3, 'h', 1670000.0, 'S', 'hockingstuart', '29/04/2017', 9.2, 3104.0, 0.0, 0.0, 0.0, 818.0, None, None, 'Boroondara', -37.7939, 145.0866, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7495, 'Balwyn North', '16 Ventnor St', 4, 'h', 1725000.0, 'PI', 'Marshall', '29/04/2017', 9.2, 3104.0, 4.0, 3.0, 2.0, 627.0, 213.0, 1970.0, 'Boroondara', -37.7827, 145.0945, 'Southern Metropolitan', 7809.0, 97.27, 4063.0, 1118.0, 95.15, 41)
# (7496, 'Bellfield', '345 Waterdale Rd', 3, 'h', 1110000.0, 'S', 'Haughton', '6/05/2017', 9.5, 3081.0, 3.0, 1.0, 2.0, 730.0, None, None, 'Banyule', -37.754, 145.0453, 'Eastern Metropolitan', 790.0, 83.66, 937.5, 291.43, 94.0, 38)
# (7497, 'Bellfield', '125 Oriel Rd', 3, 'h', 894000.0, 'S', 'Ray', '8/04/2017', 9.5, 3081.0, 3.0, 2.0, 3.0, 601.0, 101.51, 1950.0, 'Banyule', -37.7524, 145.0393, 'Eastern Metropolitan', 790.0, 83.66, 937.5, 291.43, 94.0, 38)
# (7498, 'Bentleigh', '2 Delhi St', 2, 'h', 1402000.0, 'S', 'Woodards', '6/05/2017', 13.0, 3204.0, 2.0, 1.0, 4.0, 616.0, None, None, 'Glen Eira', -37.9257, 145.0469, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7499, 'Bentleigh', '10 Luckins Rd', 3, 'h', 1500000.0, 'S', 'HAR', '6/05/2017', 13.0, 3204.0, 3.0, 1.0, 2.0, 657.0, None, None, 'Glen Eira', -37.9318, 145.0448, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7500, 'Bentleigh', '23 Auckland St', 2, 'h', 1100000.0, 'VB', 'Woodards', '8/04/2017', 13.0, 3204.0, 2.0, 1.0, 3.0, 579.0, None, None, 'Glen Eira', -37.925, 145.0467, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7501, 'Bentleigh', '28 Campbell St', 6, 'h', 2000000.0, 'VB', 'Buxton', '8/04/2017', 13.0, 3204.0, 6.0, 2.0, 2.0, 702.0, None, 1926.0, 'Glen Eira', -37.9193, 145.033, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7502, 'Bentleigh', '42 Hutchinson St', 2, 'u', 710000.0, 'S', 'Woodards', '8/04/2017', 13.0, 3204.0, 2.0, 1.0, 3.0, 225.0, None, None, 'Glen Eira', -37.9243, 145.0497, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7503, 'Bentleigh', '4/2 Jasper Rd', 2, 't', 620000.0, 'SP', 'McGrath', '8/04/2017', 13.0, 3204.0, 2.0, 2.0, 1.0, 0.0, None, 2012.0, 'Glen Eira', -37.9329, 145.0393, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7504, 'Bentleigh', '4/10 Blair St', 4, 't', 1105000.0, 'S', 'Hodges', '13/05/2017', 13.0, 3204.0, 4.0, 2.0, 1.0, 207.0, None, 2007.0, 'Glen Eira', -37.9156, 145.0355, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7505, 'Bentleigh', '23A Fromer St', 3, 't', 1303000.0, 'S', 'hockingstuart', '13/05/2017', 13.0, 3204.0, 3.0, 2.0, 2.0, 334.0, None, 2006.0, 'Glen Eira', -37.9284, 145.0428, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7506, 'Bentleigh', '197A Jasper Rd', 3, 't', 1375000.0, 'S', 'Buxton', '20/05/2017', 13.0, 3204.0, 3.0, 3.0, 2.0, 338.0, 194.0, 2012.0, 'Glen Eira', -37.9166, 145.0418, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7507, 'Bentleigh', '25B Luckins Rd', 4, 't', 1300000.0, 'S', 'hockingstuart', '20/05/2017', 13.0, 3204.0, 4.0, 2.0, 2.0, 352.0, None, None, 'Glen Eira', -37.9317, 145.0463, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7508, 'Bentleigh', '3 Rogers Rd', 3, 'h', 1286000.0, 'S', 'Woodards', '20/05/2017', 13.0, 3204.0, 3.0, 1.0, 2.0, 614.0, None, None, 'Glen Eira', -37.9317, 145.0427, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7509, 'Bentleigh', '7 Rosina St', 4, 'h', 1920000.0, 'S', 'hockingstuart', '20/05/2017', 13.0, 3204.0, 4.0, 2.0, 2.0, 650.0, None, 1996.0, 'Glen Eira', -37.9323, 145.0445, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7510, 'Bentleigh', '5 Smith St', 3, 'h', 1968500.0, 'S', 'hockingstuart', '20/05/2017', 13.0, 3204.0, 3.0, 2.0, 2.0, 674.0, None, None, 'Glen Eira', -37.9179, 145.0429, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7511, 'Bentleigh', '6b Howell St', 3, 'u', 845000.0, 'S', 'Woodards', '22/04/2017', 13.0, 3204.0, 3.0, 1.0, 2.0, 242.0, None, None, 'Glen Eira', -37.9302, 145.0331, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7512, 'Bentleigh', '8 Plym St', 4, 'h', 1107000.0, 'S', 'Woodards', '22/04/2017', 13.0, 3204.0, 4.0, 2.0, 2.0, 478.0, None, None, 'Glen Eira', -37.9321, 145.0361, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7513, 'Bentleigh', '2/23 Whitmuir Rd', 3, 'u', 641500.0, 'S', 'hockingstuart', '22/04/2017', 13.0, 3204.0, 3.0, 1.0, 1.0, 681.0, None, 1960.0, 'Glen Eira', -37.9145, 145.0287, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7514, 'Bentleigh', '52a Tucker Rd', 2, 'u', 725000.0, 'S', 'Buxton', '29/04/2017', 13.0, 3204.0, 2.0, 1.0, 1.0, 0.0, 115.0, 2006.0, 'Glen Eira', -37.9296, 145.0498, 'Southern Metropolitan', 6795.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (7515, 'Bentleigh East', '1 Melva St', 4, 'h', 1515000.0, 'S', 'Buxton', '6/05/2017', 13.9, 3165.0, 4.0, 3.0, 2.0, 635.0, 200.0, 1950.0, 'Glen Eira', -37.9107, 145.0745, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7516, 'Bentleigh East', '7 Celia St', 3, 'h', 986000.0, 'S', 'Buxton', '8/04/2017', 13.9, 3165.0, 3.0, 1.0, 3.0, 337.0, 100.0, 1950.0, 'Glen Eira', -37.9331, 145.0586, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7517, 'Bentleigh East', '1/65 Blamey St', 3, 'h', 830000.0, 'PI', 'Thomson', '13/05/2017', 13.9, 3165.0, 3.0, 1.0, 2.0, 290.0, None, 2006.0, 'Glen Eira', -37.9292, 145.0689, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7518, 'Bentleigh East', '1/32 Elizabeth St', 3, 't', 767000.0, 'S', 'Gary', '13/05/2017', 13.9, 3165.0, 3.0, 1.0, 2.0, 162.0, None, None, 'Glen Eira', -37.9229, 145.0538, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7519, 'Bentleigh East', '39 Elizabeth St', 4, 'h', 1860000.0, 'PI', 'hockingstuart', '13/05/2017', 13.9, 3165.0, 4.0, 3.0, 2.0, 620.0, None, None, 'Glen Eira', -37.9228, 145.0555, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7520, 'Bentleigh East', '122B Tambet St', 3, 't', 1200000.0, 'PI', 'Purplebricks', '13/05/2017', 13.9, 3165.0, 3.0, 2.0, 2.0, 369.0, None, None, 'Glen Eira', -37.9092, 145.0728, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7521, 'Bentleigh East', '29 Argyle St', 3, 'h', 1175000.0, 'S', 'Buxton', '20/05/2017', 13.9, 3165.0, 3.0, 1.0, 2.0, 625.0, None, None, 'Glen Eira', -37.911, 145.075, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7522, 'Bentleigh East', '28B Barrington St', 3, 't', 1225000.0, 'S', 'hockingstuart', '20/05/2017', 13.9, 3165.0, 3.0, 2.0, 2.0, 372.0, 180.0, 2008.0, 'Glen Eira', -37.9127, 145.0694, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7523, 'Bentleigh East', '1/22 Brooks St', 3, 't', 1055000.0, 'SP', 'Buxton', '20/05/2017', 13.9, 3165.0, 3.0, 2.0, 2.0, 301.0, None, 2000.0, 'Glen Eira', -37.9167, 145.077, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7524, 'Bentleigh East', '6 Elswill St', 5, 'h', 1351000.0, 'S', 'Buxton', '20/05/2017', 13.9, 3165.0, 5.0, 2.0, 2.0, 652.0, None, None, 'Glen Eira', -37.9311, 145.0651, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7525, 'Bentleigh East', '1 Heather St', 2, 'h', 1962000.0, 'S', 'Buxton', '20/05/2017', 13.9, 3165.0, 2.0, 1.0, 2.0, 848.0, None, None, 'Glen Eira', -37.9199, 145.0573, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7526, 'Bentleigh East', '1/62 Tudor St', 3, 'h', 810000.0, 'PI', 'Buxton', '20/05/2017', 13.9, 3165.0, 3.0, 1.0, 1.0, 294.0, 105.0, 1950.0, 'Glen Eira', -37.919, 145.0803, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7527, 'Bentleigh East', '2/575 Warrigal Rd', 3, 't', 850000.0, 'S', 'hockingstuart', '20/05/2017', 13.9, 3165.0, 3.0, 2.0, 2.0, 321.0, None, None, 'Glen Eira', -37.9316, 145.0806, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7528, 'Bentleigh East', '2/16 Argyle St', 2, 'u', 535000.0, 'SP', 'hockingstuart', '29/04/2017', 13.9, 3165.0, 2.0, 1.0, 1.0, 1026.0, 68.11, 1970.0, 'Glen Eira', -37.911, 145.0711, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7529, 'Bentleigh East', '4 Box Ct', 3, 'h', 1640000.0, 'S', 'Buxton', '29/04/2017', 13.9, 3165.0, 3.0, 1.0, 2.0, 733.0, None, None, 'Glen Eira', -37.9219, 145.0518, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7530, 'Bentleigh East', '2/10 Chester St', 3, 'u', 809000.0, 'S', 'Woodards', '29/04/2017', 13.9, 3165.0, 3.0, 1.0, 1.0, 289.0, None, None, 'Glen Eira', -37.9211, 145.0671, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7531, 'Bentleigh East', '13 Delma St', 3, 'h', 1510000.0, 'S', 'Buxton', '29/04/2017', 13.9, 3165.0, 3.0, 1.0, 2.0, 689.0, None, None, 'Glen Eira', -37.9317, 145.0524, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7532, 'Bentleigh East', '15 Lilac St', 4, 'h', 1292000.0, 'S', 'Woodards', '29/04/2017', 13.9, 3165.0, 4.0, 1.0, 2.0, 587.0, 161.0, 1950.0, 'Glen Eira', -37.9194, 145.05700000000004, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7533, 'Bentleigh East', '68 Mawby Rd', 3, 'h', 1165000.0, 'S', 'Buxton', '29/04/2017', 13.9, 3165.0, 3.0, 1.0, 2.0, 589.0, 158.0, None, 'Glen Eira', -37.9297, 145.0563, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7534, 'Bentleigh East', '978 North Rd', 3, 'h', 959000.0, 'S', 'Ray', '29/04/2017', 13.9, 3165.0, 3.0, 2.0, 2.0, 557.0, 119.0, 1960.0, 'Glen Eira', -37.9076, 145.06799999999996, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7535, 'Bentleigh East', '68 Tambet St', 3, 'h', 1251000.0, 'S', 'hockingstuart', '29/04/2017', 13.9, 3165.0, 3.0, 1.0, 1.0, 612.0, None, None, 'Glen Eira', -37.9133, 145.0719, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7536, 'Bentleigh East', '76 Wingate St', 3, 'h', 1205000.0, 'S', 'Buxton', '29/04/2017', 13.9, 3165.0, 3.0, 3.0, 2.0, 604.0, None, 1960.0, 'Glen Eira', -37.9362, 145.0663, 'Southern Metropolitan', 10969.0, 113.04, 2032.8, 563.2, 93.96, 51)
# (7537, 'Box Hill', '5/10 Camelia St', 2, 'u', 780000.0, 'S', 'Ray', '6/05/2017', 13.1, 3128.0, 2.0, 1.0, 1.0, 171.0, 80.0, 2014.0, 'Whitehorse', -37.8158, 145.1384, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7538, 'Box Hill', '2/13 Oxford St', 2, 'u', 572000.0, 'SP', 'Barry', '13/05/2017', 13.1, 3128.0, 2.0, 1.0, 1.0, 0.0, None, None, 'Whitehorse', -37.8219, 145.1213, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7539, 'Box Hill', '32 Sweetland Rd', 3, 'h', 910000.0, 'S', 'Fletchers', '13/05/2017', 13.1, 3128.0, 3.0, 1.0, 2.0, 414.0, None, None, 'Whitehorse', -37.8247, 145.1359, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7540, 'Box Hill', '35 Barkly St', 3, 'h', 1760000.0, 'S', 'Noel', '20/05/2017', 13.1, 3128.0, 3.0, 1.0, 2.0, 689.0, 152.0, 1920.0, 'Whitehorse', -37.8262, 145.1301, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7541, 'Box Hill', '22 Combarton St', 5, 'h', 1726000.0, 'S', 'Noel', '20/05/2017', 13.1, 3128.0, 5.0, 2.0, 2.0, 631.0, None, None, 'Whitehorse', -37.8265, 145.1276, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7542, 'Box Hill', '1A Maple St', 2, 't', 990000.0, 'S', 'Fletchers', '20/05/2017', 13.1, 3128.0, 2.0, 1.0, 1.0, 257.0, None, None, 'Whitehorse', -37.8259, 145.1282, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7543, 'Box Hill', '4/18 Barkly St', 2, 'u', 646500.0, 'S', 'McGrath', '22/04/2017', 13.1, 3128.0, 2.0, 1.0, 1.0, 156.0, None, 1980.0, 'Whitehorse', -37.8281, 145.1305, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7544, 'Box Hill', '11 Howard St', 3, 'h', 2080000.0, 'S', 'Buxton', '22/04/2017', 13.1, 3128.0, 3.0, 2.0, 2.0, 693.0, 158.0, 1925.0, 'Whitehorse', -37.8229, 145.1217, 'Eastern Metropolitan', 4605.0, 111.44, 1610.63, 426.38, 91.99, 214)
# (7545, 'Braybrook', '96 Duke St', 2, 'h', 610000.0, 'S', 'Barry', '6/05/2017', 10.8, 3019.0, 2.0, 1.0, 2.0, 555.0, 74.0, 1950.0, 'Maribyrnong', -37.7854, 144.8463, 'Western Metropolitan', 3589.0, 90.47, None, 200.0, 89.54, 15)
# (7546, 'Braybrook', '1 Hinkler St', 3, 'h', 925000.0, 'S', 'S&L', '8/04/2017', 10.8, 3019.0, 3.0, 1.0, 2.0, 597.0, None, None, 'Maribyrnong', -37.7888, 144.8511, 'Western Metropolitan', 3589.0, 90.47, None, 200.0, 89.54, 15)
# (7547, 'Braybrook', '16 Menzies St', 2, 'h', 760000.0, 'S', 'Douglas', '8/04/2017', 10.8, 3019.0, 2.0, 1.0, 1.0, 604.0, 82.0, 1950.0, 'Maribyrnong', -37.782, 144.8528, 'Western Metropolitan', 3589.0, 90.47, None, 200.0, 89.54, 15)
# (7548, 'Braybrook', '14 Arthur St', 3, 'h', 771000.0, 'S', 'S&L', '20/05/2017', 10.8, 3019.0, 3.0, 1.0, 0.0, 556.0, None, None, 'Maribyrnong', -37.7904, 144.8514, 'Western Metropolitan', 3589.0, 90.47, None, 200.0, 89.54, 15)
# (7549, 'Braybrook', '13/25 Marnoo St', 3, 't', 441700.0, 'SP', 'Barry', '22/04/2017', 10.8, 3019.0, 3.0, 2.0, 1.0, 145.0, 107.0, 2003.0, 'Maribyrnong', -37.7894, 144.8463, 'Western Metropolitan', 3589.0, 90.47, None, 200.0, 89.54, 15)
# (7550, 'Braybrook', '10 Sedge Cl', 4, 'h', 1000000.0, 'S', 'Nelson', '22/04/2017', 10.8, 3019.0, 4.0, 3.0, 2.0, 475.0, 319.0, 2002.0, 'Maribyrnong', -37.7759, 144.8552, 'Western Metropolitan', 3589.0, 90.47, None, 200.0, 89.54, 15)
# (7551, 'Braybrook', '30 Shepherd St', 3, 'h', 730000.0, 'SP', 'Village', '29/04/2017', 10.8, 3019.0, 3.0, 1.0, 3.0, 586.0, None, None, 'Maribyrnong', -37.783, 144.855, 'Western Metropolitan', 3589.0, 90.47, None, 200.0, 89.54, 15)
# (7552, 'Brighton', '33 Brickwood St', 3, 'h', 2575000.0, 'S', 'Marshall', '8/04/2017', 11.2, 3186.0, 3.0, 2.0, 2.0, 517.0, 195.0, 1920.0, 'Bayside', -37.894, 144.9977, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7553, 'Brighton', '81 Carpenter St', 4, 't', 2900000.0, 'VB', 'Kay', '8/04/2017', 11.2, 3186.0, 4.0, 4.0, 2.0, 473.0, 292.0, 2013.0, 'Bayside', -37.9104, 144.9999, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7554, 'Brighton', '161 Church St', 5, 'h', 5800000.0, 'PI', 'Castran', '8/04/2017', 11.2, 3186.0, 5.0, 4.0, 4.0, 1276.0, None, 1880.0, 'Bayside', -37.9164, 144.9974, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7555, 'Brighton', '36 Meek St', 3, 'h', 2140000.0, 'S', 'hockingstuart', '8/04/2017', 11.2, 3186.0, 3.0, 2.0, 2.0, 393.0, None, None, 'Bayside', -37.902, 144.9922, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7556, 'Brighton', '2 Normanby St', 3, 'h', 2225000.0, 'PI', 'Nick', '8/04/2017', 11.2, 3186.0, 3.0, 2.0, 2.0, 0.0, 167.0, 1980.0, 'Bayside', -37.911, 144.9866, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7557, 'Brighton', '147 North Rd', 2, 't', 975000.0, 'PI', 'Marshall', '8/04/2017', 11.2, 3186.0, 2.0, 1.0, 1.0, 444.0, 182.0, 1915.0, 'Bayside', -37.8993, 145.0046, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7558, 'Brighton', '24 North Rd', 4, 'h', 4225000.0, 'S', 'Biggin', '8/04/2017', 11.2, 3186.0, 4.0, 2.0, 2.0, 920.0, 333.0, 1990.0, 'Bayside', -37.8981, 144.9902, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7559, 'Brighton', '8/20 Yuille St', 3, 't', 2100000.0, 'S', 'Buxton', '8/04/2017', 11.2, 3186.0, 3.0, 2.0, 4.0, 0.0, 145.0, 1970.0, 'Bayside', -37.928, 145.0002, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7560, 'Brighton', '3/136 New St', 3, 'u', 1392000.0, 'S', 'hockingstuart', '13/05/2017', 11.2, 3186.0, 3.0, 2.0, 1.0, 188.0, None, None, 'Bayside', -37.9181, 144.9933, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7561, 'Brighton', '552 New St', 3, 'h', 2445000.0, 'S', 'Marshall', '13/05/2017', 11.2, 3186.0, 3.0, 3.0, 2.0, 440.0, None, None, 'Bayside', -37.8868, 144.9968, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7562, 'Brighton', '38/568 New St', 2, 'u', 520000.0, 'PI', 'hockingstuart', '13/05/2017', 11.2, 3186.0, 2.0, 1.0, 1.0, 1647.0, 73.0, 2004.0, 'Bayside', -37.8847, 144.9972, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7563, 'Brighton', '3/1 Thomson St', 4, 'h', 2000000.0, 'VB', 'Kay', '13/05/2017', 11.2, 3186.0, 4.0, 2.0, 2.0, 286.0, 283.0, 1999.0, 'Bayside', -37.8981, 145.0, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7564, 'Brighton', '39 Warleigh Gr', 2, 'h', 1350000.0, 'S', 'Hodges', '13/05/2017', 11.2, 3186.0, 2.0, 1.0, 1.0, 873.0, None, None, 'Bayside', -37.9043, 145.0048, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7565, 'Brighton', '138 Bay St', 3, 'h', 1900000.0, 'S', 'hockingstuart', '20/05/2017', 11.2, 3186.0, 3.0, 2.0, 3.0, 503.0, None, None, 'Bayside', -37.9049, 144.9969, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7566, 'Brighton', '1/21 Brickwood St', 2, 'u', 1002500.0, 'S', 'hockingstuart', '20/05/2017', 11.2, 3186.0, 2.0, 1.0, 1.0, 118.0, None, 1975.0, 'Bayside', -37.8953, 144.9974, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7567, 'Brighton', '3 Hayball Ct', 4, 'h', 2415000.0, 'S', 'Buxton', '20/05/2017', 11.2, 3186.0, 4.0, 3.0, 2.0, 402.0, None, None, 'Bayside', -37.9037, 144.9926, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7568, 'Brighton', '1/76 Whyte St', 2, 't', 1055000.0, 'S', 'Marshall', '20/05/2017', 11.2, 3186.0, 2.0, 1.0, 2.0, 211.0, None, 1970.0, 'Bayside', -37.921, 144.9999, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7569, 'Brighton', '56 Asling St', 3, 't', 1990000.0, 'S', 'Buxton', '22/04/2017', 11.2, 3186.0, 3.0, 2.0, 2.0, 0.0, 189.0, 1935.0, 'Bayside', -37.901, 145.0026, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7570, 'Brighton', '5 Blairgowrie Ct', 3, 'h', 3025000.0, 'PI', 'Biggin', '22/04/2017', 11.2, 3186.0, 3.0, 2.0, 4.0, 649.0, 195.0, 1967.0, 'Bayside', -37.9056, 144.9893, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7571, 'Brighton', '868 Hampton St', 3, 'h', 1502000.0, 'S', 'Weston', '22/04/2017', 11.2, 3186.0, 3.0, 1.0, 1.0, 431.0, None, None, 'Bayside', -37.9107, 145.0077, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7572, 'Brighton', '3/12 Wellington St', 3, 'u', 1221000.0, 'S', 'Nick', '22/04/2017', 11.2, 3186.0, 3.0, 2.0, 2.0, 0.0, 109.0, 1975.0, 'Bayside', -37.9163, 144.9901, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7573, 'Brighton', '3/30 Grosvenor St', 4, 'h', 2550000.0, 'SP', 'Hodges', '29/04/2017', 11.2, 3186.0, 4.0, 3.0, 2.0, 263.0, None, 2005.0, 'Bayside', -37.9099, 144.9899, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7574, 'Brighton', '3 Rose St', 2, 't', 1470000.0, 'S', 'Hodges', '29/04/2017', 11.2, 3186.0, 2.0, 1.0, 1.0, 238.0, None, None, 'Bayside', -37.8985, 145.0048, 'Southern Metropolitan', 10579.0, 268.3, 5467.08, 1029.46, 95.23, 124)
# (7575, 'Brighton East', '1/373 South Rd', 3, 'u', 725000.0, 'S', 'Buxton', '8/04/2017', 10.7, 3187.0, 3.0, 1.0, 1.0, 137.0, None, None, 'Bayside', -37.9319, 145.0282, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7576, 'Brighton East', '7 Billson St', 5, 'h', 2140000.0, 'S', 'Marshall', '13/05/2017', 10.7, 3187.0, 5.0, 2.0, 2.0, 780.0, 206.0, 1950.0, 'Bayside', -37.9173, 145.0142, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7577, 'Brighton East', '36 Clinton St', 4, 'h', 1630000.0, 'S', 'RT', '13/05/2017', 10.7, 3187.0, 4.0, 2.0, 1.0, 596.0, None, None, 'Bayside', -37.9113, 145.0207, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7578, 'Brighton East', '4/25 Cluden St', 2, 'u', 910000.0, 'S', 'Woodards', '13/05/2017', 10.7, 3187.0, 2.0, 1.0, 3.0, 238.0, None, None, 'Bayside', -37.9126, 145.0105, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7579, 'Brighton East', '1 Curzon St', 3, 'h', 1975000.0, 'S', 'Kay', '13/05/2017', 10.7, 3187.0, 3.0, 1.0, 2.0, 688.0, None, None, 'Bayside', -37.9212, 145.013, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7580, 'Brighton East', '40 Hodder St', 3, 'h', 1635000.0, 'S', 'Buxton', '13/05/2017', 10.7, 3187.0, 3.0, 1.0, 1.0, 597.0, 131.0, 1925.0, 'Bayside', -37.9064, 145.0229, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7581, 'Brighton East', '22 Milliara Gr', 8, 'h', 1880000.0, 'VB', 'Buxton', '13/05/2017', 10.7, 3187.0, 8.0, 3.0, 3.0, 614.0, None, None, 'Bayside', -37.9097, 145.0161, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7582, 'Brighton East', '5 Valdemar Ct', 3, 'h', 1743000.0, 'S', 'Marshall', '13/05/2017', 10.7, 3187.0, 3.0, 1.0, 2.0, 590.0, None, None, 'Bayside', -37.9287, 145.0273, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7583, 'Brighton East', '12 Agnew St', 3, 'h', 2291000.0, 'S', 'Marshall', '20/05/2017', 10.7, 3187.0, 3.0, 2.0, 2.0, 530.0, None, 1886.0, 'Bayside', -37.9119, 145.011, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7584, 'Brighton East', '7 Roberts Ct', 3, 'h', 1270000.0, 'VB', 'Ray', '20/05/2017', 10.7, 3187.0, 3.0, 1.0, 3.0, 724.0, None, None, None, -37.9291, 145.0297, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7585, 'Brighton East', '239 South Rd', 3, 'h', 1400000.0, 'S', 'Buxton', '20/05/2017', 10.7, 3187.0, 3.0, 1.0, 2.0, 677.0, None, None, 'Bayside', -37.9304, 145.0151, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7586, 'Brighton East', '6 Coronation St', 3, 'h', 1640000.0, 'S', 'Hodges', '22/04/2017', 10.7, 3187.0, 3.0, 1.0, 1.0, 590.0, None, None, 'Bayside', -37.9012, 145.00799999999995, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7587, 'Brighton East', '7 Holmhurst Ct', 4, 't', 1700000.0, 'PI', 'Hodges', '29/04/2017', 10.7, 3187.0, 4.0, 3.0, 2.0, 312.0, 118.0, 1950.0, 'Bayside', -37.9295, 145.0144, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7588, 'Brighton East', '55 Milroy St', 5, 'h', 1900000.0, 'PI', 'Hodges', '29/04/2017', 10.7, 3187.0, 5.0, 3.0, 2.0, 583.0, 271.0, 2009.0, 'Bayside', -37.9057, 145.0101, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7589, 'Brighton East', '7/36 Union St', 3, 't', 972000.0, 'S', 'Gary', '29/04/2017', 10.7, 3187.0, 3.0, 2.0, 1.0, 119.0, 160.0, 2000.0, 'Bayside', -37.9084, 145.0118, 'Southern Metropolitan', 6938.0, 193.87, 1116.0, 376.88, 93.35, 53)
# (7590, 'Brunswick', '129 Glenlyon Rd', 3, 'h', 1652000.0, 'S', 'Jellis', '6/05/2017', 5.2, 3056.0, 3.0, 1.0, 2.0, 506.0, 196.8, 1921.0, 'Moreland', -37.7723, 144.9694, 'Northern Metropolitan', 11918.0, 94.67, 2308.98, 618.76, 94.76, 446)
# (7591, 'Brunswick', '3/15 Mitchell St', 2, 'u', 735000.0, 'SP', 'Walshe', '6/05/2017', 5.2, 3056.0, 2.0, 1.0, 2.0, 173.0, 77.0, 1970.0, 'Moreland', -37.7586, 144.9653, 'Northern Metropolitan', 11918.0, 94.67, 2308.98, 618.76, 94.76, 446)
# (7592, 'Brunswick', '217 Victoria St', 3, 'h', 1210000.0, 'S', 'Woodards', '6/05/2017', 5.2, 3056.0, 3.0, 1.0, 0.0, 282.0, 112.0, 1900.0, 'Moreland', -37.7674, 144.966, 'Northern Metropolitan', 11918.0, 94.67, 2308.98, 618.76, 94.76, 446)
# ...
# (12325, 'Glenroy', '133 Morell St', 3, 'h', 780000.0, 'SP', 'Stockdale', '3/09/2017', 11.2, 3046.0, 3.0, 1.0, 3.0, 618.0, 116.0, 1960.0, None, -37.69836, 144.93891000000005, 'Northern Metropolitan', 8870.0, 69.03, 1076.67, 351.0, 94.92, 60)
# (12326, 'Gowanbrae', '4/74 Rutherglen Cr', 4, 'h', 635000.0, 'SP', 'Stockdale', '3/09/2017', 12.9, 3043.0, 4.0, 2.0, 2.0, 2679.0, 4.0, 2005.0, None, -37.70207, 144.89805, 'Western Metropolitan', 1071.0, 114.83, 1502.0, 700.0, 93.38, 29)
# (12327, 'Greensborough', '34 Warralong Av', 3, 'h', 700000.0, 'VB', 'Nelson', '3/09/2017', 16.1, 3088.0, 3.0, 1.0, 2.0, 676.0, None, None, None, -37.71825, 145.09488000000005, 'Northern Metropolitan', 8524.0, 68.36, 955.0, 250.0, 95.17, 11)
# (12328, 'Greenvale', '35 Hermitage Dr', 4, 'h', 797000.0, 'S', 'Barry', '3/09/2017', 20.4, 3059.0, 4.0, 2.0, 2.0, 1057.0, 195.0, 1995.0, None, -37.65467, 144.9035, 'Northern Metropolitan', 4864.0, 136.41, 1612.67, 420.67, 98.0, 17)
# (12329, 'Hampton', '11 Bridge St', 4, 'h', 2675000.0, 'S', 'Nick', '3/09/2017', 13.8, 3188.0, 4.0, 2.0, 4.0, 728.0, None, None, None, -37.94437, 145.00288, 'Southern Metropolitan', 5454.0, 245.11, 4694.56, 1273.6, 97.87, 71)
# (12330, 'Hampton', '32 Retreat Rd', 4, 'h', 1900000.0, 'VB', 'Marshall', '3/09/2017', 13.8, 3188.0, 4.0, 3.0, 2.0, 699.0, 228.0, 1985.0, None, -37.94088, 145.0145, 'Southern Metropolitan', 5454.0, 245.11, 4694.56, 1273.6, 97.87, 71)
# (12331, 'Hampton', '20 Teddington Rd', 4, 'h', 2260000.0, 'S', 'Buxton', '3/09/2017', 13.8, 3188.0, 4.0, 2.0, 2.0, 766.0, None, None, None, -37.93571, 145.0153, 'Southern Metropolitan', 5454.0, 245.11, 4694.56, 1273.6, 97.87, 71)
# (12332, 'Highett', '48 Turner Rd', 2, 'h', 832000.0, 'S', 'Buxton', '3/09/2017', 16.0, 3190.0, 2.0, 1.0, 1.0, 254.0, None, None, None, -37.95188, 145.05369, 'Southern Metropolitan', 4794.0, 154.56, 3421.4, 832.6, 93.59, 39)
# (12333, 'Hoppers Crossing', '2 Jasmine Cl', 5, 'h', 610000.0, 'SA', 'hockingstuart', '3/09/2017', 18.4, 3029.0, 5.0, 2.0, 2.0, 650.0, None, None, None, -37.85638, 144.70671000000004, 'Western Metropolitan', 13830.0, 76.15, 1692.0, 512.86, 93.87, 113)
# (12334, 'Hoppers Crossing', '30 Strang St', 4, 'h', 555000.0, 'PI', 'Barry', '3/09/2017', 18.4, 3029.0, 4.0, 1.0, 2.0, 570.0, None, None, None, -37.87552, 144.69648, 'Western Metropolitan', 13830.0, 76.15, 1692.0, 512.86, 93.87, 113)
# (12335, 'Huntingdale', '3 Worcester St', 3, 'h', 1080000.0, 'S', 'Buxton', '3/09/2017', 12.3, 3166.0, 3.0, 1.0, 3.0, 594.0, None, None, None, -37.9028, 145.10605, 'Southern Metropolitan', 768.0, 113.14, 1536.17, 459.29, 89.13, 70)
# (12336, 'Kealba', '2 Stewart Cl', 5, 'h', 750000.0, 'SP', 'Brad', '3/09/2017', 14.0, 3021.0, 5.0, 2.0, 4.0, 647.0, 207.0, 1983.0, None, -37.73726, 144.82998, 'Western Metropolitan', 1202.0, 81.65, 1300.0, 350.0, 89.85, 20)
# (12337, 'Keilor East', '49 Roberts St', 4, 'h', 1010000.0, 'S', 'Nelson', '3/09/2017', 11.7, 3033.0, 4.0, 1.0, 2.0, 612.0, None, None, None, -37.75035, 144.86431000000005, 'Western Metropolitan', 5629.0, 83.64, 850.0, 306.67, 93.86, 14)
# (12338, 'Kew', '8 Bradford Av', 4, 'h', 3060000.0, 'S', 'RT', '3/09/2017', 5.4, 3101.0, 4.0, 2.0, 2.0, 838.0, None, None, None, -37.80894, 145.05853000000005, 'Southern Metropolitan', 10331.0, 139.6, 1300.0, 609.75, 92.84, 107)
# (12339, 'Kew', '57 Derby St', 4, 'h', 1690000.0, 'S', 'Nelson', '3/09/2017', 5.4, 3101.0, 4.0, 2.0, 4.0, 350.0, 168.0, 1900.0, None, -37.80127, 145.03733, 'Southern Metropolitan', 10331.0, 139.6, 1300.0, 609.75, 92.84, 107)
# (12340, 'Kew East', '9 Tanner Av', 4, 'h', 1600000.0, 'VB', 'Noel', '3/09/2017', 7.3, 3102.0, 4.0, 2.0, 2.0, 12300.0, None, 1940.0, None, -37.79459, 145.03921, 'Southern Metropolitan', 2671.0, 759.08, 5627.0, 1589.0, 89.33, 12)
# (12341, 'Lalor', '20 Dunbar Ct', 3, 'h', 685000.0, 'S', 'Ray', '3/09/2017', 16.3, 3075.0, 3.0, 1.0, 2.0, 888.0, None, None, None, -37.66075, 145.01133000000004, 'Northern Metropolitan', 8279.0, 142.8, 800.0, 200.0, 88.29, 10)
# (12342, 'Lalor', '123 Gillwell Rd', 4, 'h', 715000.0, 'S', 'Barry', '3/09/2017', 16.3, 3075.0, 4.0, 2.0, 2.0, 500.0, None, None, None, -37.65936, 144.9967, 'Northern Metropolitan', 8279.0, 142.8, 800.0, 200.0, 88.29, 10)
# (12343, 'Lalor', '1 Nebel St', 3, 'h', 685500.0, 'S', 'HAR', '3/09/2017', 16.3, 3075.0, 3.0, 1.0, 1.0, 551.0, None, None, None, -37.66613, 145.01346999999996, 'Northern Metropolitan', 8279.0, 142.8, 800.0, 200.0, 88.29, 10)
# (12344, 'Maidstone', '2/9 Havelock St', 3, 't', 722000.0, 'S', 'Biggin', '3/09/2017', 6.4, 3012.0, 3.0, 2.0, 2.0, 147.0, 125.0, 2015.0, None, -37.78538, 144.87958999999995, 'Western Metropolitan', 3873.0, 112.63, 2335.0, 518.0, 94.0, 76)
# (12345, 'Malvern East', '3 Carmelo Av', 3, 'h', 1430000.0, 'S', 'Buxton', '3/09/2017', 8.4, 3145.0, 3.0, 1.0, 1.0, 641.0, None, None, None, -37.87811, 145.07778000000005, 'Southern Metropolitan', 8801.0, 116.27, 980.0, 416.54, 92.39, 116)
# (12346, 'Maribyrnong', '6 Adori Pl', 3, 'h', 983000.0, 'S', 'Biggin', '3/09/2017', 4.3, 3032.0, 3.0, 2.0, 2.0, 359.0, 185.0, 2008.0, None, -37.78606, 144.88459, 'Western Metropolitan', 4918.0, 111.61, 1677.92, 469.87, 94.29, 176)
# (12347, 'Meadow Heights', '31 Buchan St', 4, 'h', 560000.0, 'S', 'Stockdale', '3/09/2017', 17.4, 3048.0, 4.0, 3.0, 2.0, 572.0, None, None, None, -37.65465, 144.92182, 'Northern Metropolitan', 4704.0, 57.5, None, None, 95.33, 4)
# (12348, 'Meadow Heights', '9 Hibiscus Cl', 3, 'h', 482000.0, 'S', 'Nelson', '3/09/2017', 17.4, 3048.0, 3.0, 2.0, 2.0, 452.0, 140.0, 1992.0, None, -37.64023, 144.91398999999996, 'Northern Metropolitan', 4704.0, 57.5, None, None, 95.33, 4)
# (12349, 'Melton', '1 Carina Dr', 5, 'h', 460000.0, 'S', 'hockingstuart', '3/09/2017', 31.7, 3337.0, 5.0, 2.0, 2.0, 590.0, None, None, None, -37.68217, 144.56926, 'Western Victoria', 3600.0, 110.81, None, None, 93.93, 26)
# (12350, 'Melton', '20 Perry Cl', 3, 'h', 430000.0, 'S', 'hockingstuart', '3/09/2017', 31.7, 3337.0, 3.0, 1.0, 2.0, 583.0, 103.0, 1980.0, None, -37.68146, 144.57106000000005, 'Western Victoria', 3600.0, 110.81, None, None, 93.93, 26)
# (12351, 'Melton West', '30 Borrowdale Rd', 3, 'h', 438000.0, 'S', 'YPA', '3/09/2017', 31.7, 3337.0, 3.0, 2.0, 2.0, 575.0, 172.0, 2016.0, None, -37.66745, 144.55857, 'Northern Victoria', 6065.0, 110.81, None, None, 93.93, 26)
# (12352, 'Mentone', '14 Glengala Ct', 4, 'h', 900000.0, 'PI', 'Hodges', '3/09/2017', 20.0, 3194.0, 4.0, 2.0, 2.0, 530.0, 216.0, 1980.0, None, -37.98368, 145.09237, 'South-Eastern Metropolitan', 6162.0, 153.0, 1500.0, None, 94.56, 21)
# (12353, 'Mentone', '9 Glengala Ct', 3, 'h', 960500.0, 'S', 'Buxton', '3/09/2017', 20.0, 3194.0, 3.0, 2.0, 2.0, 535.0, 132.0, 1985.0, None, -37.98329, 145.0918, 'South-Eastern Metropolitan', 6162.0, 153.0, 1500.0, None, 94.56, 21)
# (12354, 'Mentone', '108 Oak Av', 3, 't', 840000.0, 'S', 'Obrien', '3/09/2017', 20.0, 3194.0, 3.0, 2.0, 2.0, 163.0, 154.0, 2012.0, None, -37.97459, 145.06937, 'South-Eastern Metropolitan', 6162.0, 153.0, 1500.0, None, 94.56, 21)
# (12355, 'Moonee Ponds', '86 Waverley St', 3, 'h', 1210000.0, 'PI', 'Sweeney', '3/09/2017', 6.2, 3039.0, 3.0, 2.0, 0.0, 411.0, 114.0, 1915.0, None, -37.76285, 144.90575, 'Western Metropolitan', 6232.0, 100.98, 1533.33, 392.5, 94.31, 52)
# (12356, 'Moonee Ponds', '38 Wilson St', 4, 'h', 1450000.0, 'S', 'Nelson', '3/09/2017', 6.2, 3039.0, 4.0, 2.0, 3.0, 465.0, None, None, None, -37.76306, 144.92851000000005, 'Western Metropolitan', 6232.0, 100.98, 1533.33, 392.5, 94.31, 52)
# (12357, 'Moorabbin', '2 Marrbridge Rd', 4, 'h', 1188000.0, 'S', 'Ray', '3/09/2017', 14.3, 3189.0, 4.0, 2.0, 2.0, 595.0, None, None, None, -37.94253, 145.05911, 'Southern Metropolitan', 2555.0, 97.0, None, None, 96.4, 13)
# (12358, 'Mordialloc', '13 Montgomery St', 2, 'h', 1300000.0, 'VB', 'Buxton', '3/09/2017', 21.5, 3195.0, 2.0, 1.0, 2.0, 502.0, None, None, None, -38.00663, 145.08491999999995, 'South-Eastern Metropolitan', 3650.0, 143.04, 2539.0, 649.29, 94.47, 71)
# (12359, 'Mount Waverley', '12 Beverley Gr', 3, 'h', 1800000.0, 'PI', 'McGrath', '3/09/2017', 14.2, 3149.0, 3.0, 2.0, 2.0, 786.0, None, None, None, -37.87834, 145.12131000000005, 'Eastern Metropolitan', 13366.0, 119.42, 1588.5, 450.29, 94.58, 77)
# (12360, 'Mulgrave', '3 Doull Ct', 3, 't', 650000.0, 'S', 'Ray', '3/09/2017', 18.8, 3170.0, 3.0, 2.0, 1.0, 145.0, 129.0, 2015.0, None, -37.93211, 145.18955, 'South-Eastern Metropolitan', 7113.0, 59.45, None, None, 96.79, 22)
# (12361, 'Mulgrave', '63 Haverbrack Dr', 4, 'h', 1105000.0, 'S', 'Ray', '3/09/2017', 18.8, 3170.0, 4.0, 3.0, 2.0, 650.0, 224.0, 1985.0, None, -37.92979, 145.2036, 'South-Eastern Metropolitan', 7113.0, 59.45, None, None, 96.79, 22)
# (12362, 'Newport', '11 Collingwood Rd', 4, 'h', 1180000.0, 'PI', 'Williams', '3/09/2017', 6.2, 3015.0, 4.0, 1.0, None, 545.0, None, None, None, -37.84399000000001, 144.89125, 'Western Metropolitan', 5498.0, 132.05, 2002.33, 706.12, 95.29, 65)
# (12363, 'Newport', '88 Maddox Rd', 4, 't', 940000.0, 'SP', 'Greg', '3/09/2017', 6.2, 3015.0, 4.0, 2.0, 2.0, 510.0, 196.0, 2016.0, None, -37.84815, 144.86866, 'Western Metropolitan', 5498.0, 132.05, 2002.33, 706.12, 95.29, 65)
# (12364, 'Niddrie', '40 Hotham Rd', 2, 'h', 1370000.0, 'S', 'Frank', '3/09/2017', 10.4, 3042.0, 2.0, 1.0, 0.0, 650.0, None, None, None, -37.73612, 144.88474, 'Western Metropolitan', 2291.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (12365, 'Niddrie', '60 Muriel St', 5, 'h', 1215000.0, 'S', 'Nelson', '3/09/2017', 10.4, 3042.0, 5.0, 2.0, 2.0, 647.0, None, None, None, -37.74269, 144.88607, 'Western Metropolitan', 2291.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (12366, 'Niddrie', '36 Shaw St', 2, 'h', 1300000.0, 'PI', 'Barry', '3/09/2017', 10.4, 3042.0, 2.0, 1.0, 1.0, 650.0, 380.0, 2016.0, None, -37.74016, 144.88805, 'Western Metropolitan', 2291.0, 81.57, 1800.75, 568.2, 95.52, 35)
# (12367, 'North Melbourne', '181 Abbotsford St', 2, 'h', 1100000.0, 'PI', 'Nelson', '3/09/2017', 1.8, 3051.0, 2.0, 1.0, 0.0, 129.0, None, 1880.0, None, -37.80318, 144.94513, 'Northern Metropolitan', 6821.0, 112.23, 3152.15, 753.53, 92.88, 338)
# (12368, 'North Melbourne', '31 Cobden St', 3, 'h', 1425000.0, 'S', 'Nelson', '3/09/2017', 1.8, 3051.0, 3.0, 1.0, 3.0, 163.0, None, None, None, -37.80452, 144.95718, 'Northern Metropolitan', 6821.0, 112.23, 3152.15, 753.53, 92.88, 338)
# (12369, 'North Melbourne', '60 Shiel St', 3, 'h', 1550000.0, 'S', 'Nelson', '3/09/2017', 1.8, 3051.0, 3.0, 2.0, 1.0, 173.0, None, None, None, -37.79614, 144.94248000000005, 'Northern Metropolitan', 6821.0, 112.23, 3152.15, 753.53, 92.88, 338)
# (12370, 'Northcote', '28 Plant St', 2, 'h', 1386000.0, 'S', 'Love', '3/09/2017', 5.3, 3070.0, 2.0, 1.0, 0.0, 270.0, None, None, None, -37.77816, 144.99995, 'Northern Metropolitan', 11364.0, 113.28, 2429.34, 585.76, 95.53, 284)
# (12371, 'Northcote', '38 Whalley St', 4, 'h', 1700000.0, 'S', 'McGrath', '3/09/2017', 5.3, 3070.0, 4.0, 3.0, 4.0, 422.0, None, None, None, -37.76969, 145.00718, 'Northern Metropolitan', 11364.0, 113.28, 2429.34, 585.76, 95.53, 284)
# (12372, 'Oakleigh', '3 Ford Av', 4, 'h', 1150000.0, 'VB', 'Woodards', '3/09/2017', 12.3, 3166.0, 4.0, 2.0, 2.0, 1060.0, 175.0, 1940.0, None, -37.9073, 145.0962, 'Southern Metropolitan', 3224.0, 113.14, 1536.17, 459.29, 89.13, 70)
# (12373, 'Oakleigh South', '10 Talbot Av', 3, 'h', 1140000.0, 'PI', 'Buxton', '3/09/2017', 15.5, 3167.0, 3.0, 1.0, 4.0, 697.0, None, None, None, -37.92021, 145.10442, 'South-Eastern Metropolitan', 3692.0, 107.22, None, None, 92.85, 23)
# (12374, 'Ormond', '26 Thompson St', 5, 'h', 2110000.0, 'PI', 'Marshall', '3/09/2017', 11.4, 3204.0, 5.0, 3.0, 4.0, 664.0, 245.0, 1980.0, None, -37.90422, 145.02827, 'Southern Metropolitan', 3578.0, 114.61, 2936.0, 719.22, 94.6, 80)
# (12375, 'Parkdale', '2 Kershaw St', 4, 'h', 1320000.0, 'S', 'Hodges', '3/09/2017', 21.5, 3195.0, 4.0, 2.0, 5.0, 600.0, 179.0, 1950.0, None, -37.99806, 145.08829, 'South-Eastern Metropolitan', 5087.0, 143.04, 2539.0, 649.29, 94.47, 71)
# (12376, 'Parkdale', '8/410 Nepean Hwy', 2, 'u', 672000.0, 'S', 'Hodges', '3/09/2017', 21.5, 3195.0, 2.0, 1.0, 1.0, 158.0, None, None, None, -37.99515, 145.08222, 'South-Eastern Metropolitan', 5087.0, 143.04, 2539.0, 649.29, 94.47, 71)
# (12377, 'Pascoe Vale', '3/43 Danin St', 3, 't', 676000.0, 'S', 'Brad', '3/09/2017', 8.5, 3044.0, 3.0, 2.0, 2.0, 122.0, 108.0, 2012.0, None, -37.72304000000001, 144.92864, 'Northern Metropolitan', 7485.0, 98.95, 1567.5, 514.2, 96.19, 40)
# (12378, 'Pascoe Vale', '5/14 Devon Rd', 2, 't', 500000.0, 'VB', 'Nelson', '3/09/2017', 8.5, 3044.0, 2.0, 2.0, 1.0, 74.0, None, 2011.0, None, -37.72184, 144.92969, 'Northern Metropolitan', 7485.0, 98.95, 1567.5, 514.2, 96.19, 40)
# (12379, 'Pascoe Vale', '52 Prospect St', 3, 'h', 1010000.0, 'S', 'Jellis', '3/09/2017', 8.5, 3044.0, 3.0, 1.0, 2.0, 673.0, None, 1970.0, None, -37.72777, 144.9339, 'Northern Metropolitan', 7485.0, 98.95, 1567.5, 514.2, 96.19, 40)
# (12380, 'Pascoe Vale', '33 Snell Gr', 4, 'h', 1375000.0, 'VB', 'Nelson', '3/09/2017', 8.5, 3044.0, 4.0, 2.0, 2.0, 1031.0, None, None, None, -37.71746, 144.92955, 'Northern Metropolitan', 7485.0, 98.95, 1567.5, 514.2, 96.19, 40)
# (12381, 'Point Cook', '114 Fongeo Dr', 3, 'h', 540000.0, 'S', 'Barry', '3/09/2017', 14.7, 3030.0, 3.0, 2.0, 2.0, 353.0, 135.0, 2011.0, None, -37.9105, 144.73457, 'Western Metropolitan', 15542.0, 115.75, 2224.6, 590.0, 94.72, 258)
# (12382, 'Port Melbourne', '711/101 Bay St', 2, 'u', 820000.0, 'SP', 'Chisholm', '3/09/2017', 3.5, 3207.0, 2.0, 2.0, 2.0, 4604.0, None, None, None, -37.84079000000001, 144.94002, 'Southern Metropolitan', 8648.0, 200.21, 4743.96, 1480.79, 95.02, 257)
# (12383, 'Port Melbourne', '333 Princes St', 3, 'h', 1764000.0, 'S', 'Buxton', '3/09/2017', 3.5, 3207.0, 3.0, 2.0, None, 131.0, 133.0, 1900.0, None, -37.83509, 144.94224, 'Southern Metropolitan', 8648.0, 200.21, 4743.96, 1480.79, 95.02, 257)
# (12384, 'Port Melbourne', '297 Ross St', 4, 'h', 2625000.0, 'PI', 'Marshall', '3/09/2017', 3.5, 3207.0, 4.0, 3.0, 2.0, 202.0, None, None, None, -37.83247, 144.94212, 'Southern Metropolitan', 8648.0, 200.21, 4743.96, 1480.79, 95.02, 257)
# (12385, 'Prahran', '13 Bowen St', 2, 'h', 1400000.0, 'PI', 'hockingstuart', '3/09/2017', 4.6, 3181.0, 2.0, 1.0, 0.0, 212.0, None, None, None, -37.85491, 145.00373000000005, 'Southern Metropolitan', 7717.0, 148.17, 3304.38, 868.15, 95.74, 460)
# (12386, 'Reservoir', '11 Asquith St', 4, 'h', 750000.0, 'VB', 'Stockdale', '3/09/2017', 12.0, 3073.0, 4.0, 1.0, 6.0, 953.0, None, None, None, -37.69693, 145.0079, 'Northern Metropolitan', 21650.0, 273.93, 1459.63, 399.89, 92.57, 68)
# (12387, 'Reservoir', '1 Cameron St', 3, 'h', 861000.0, 'S', 'Stockdale', '3/09/2017', 12.0, 3073.0, 3.0, 2.0, 3.0, 488.0, 135.0, 1950.0, None, -37.72747, 145.00035, 'Northern Metropolitan', 21650.0, 273.93, 1459.63, 399.89, 92.57, 68)
# (12388, 'Reservoir', '39 Crevelli St', 3, 'h', 612500.0, 'S', 'Stockdale', '3/09/2017', 12.0, 3073.0, 3.0, 1.0, 1.0, 170.0, 128.0, 1950.0, None, -37.72924, 145.02981, 'Northern Metropolitan', 21650.0, 273.93, 1459.63, 399.89, 92.57, 68)
# (12389, 'Reservoir', '98 Crookston Rd', 3, 'h', 906000.0, 'S', 'Barry', '3/09/2017', 12.0, 3073.0, 3.0, 1.0, 2.0, 741.0, None, None, None, -37.70931, 145.01434, 'Northern Metropolitan', 21650.0, 273.93, 1459.63, 399.89, 92.57, 68)
# (12390, 'Reservoir', '21 Hughes Pde', 3, 'h', 758000.0, 'S', 'Barry', '3/09/2017', 12.0, 3073.0, 3.0, 1.0, 2.0, 558.0, None, None, None, -37.69968, 145.0054, 'Northern Metropolitan', 21650.0, 273.93, 1459.63, 399.89, 92.57, 68)
# (12391, 'Reservoir', '79 North Rd', 4, 'h', 900000.0, 'SP', 'RW', '3/09/2017', 12.0, 3073.0, 4.0, 1.0, 4.0, 646.0, 119.0, 1950.0, None, -37.72328, 145.01862, 'Northern Metropolitan', 21650.0, 273.93, 1459.63, 399.89, 92.57, 68)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Ejercicio 2:
#
# 1. Seleccionar un subconjunto de columnas que les parezcan relevantes al problema de predicción del valor de la propiedad. Justificar las columnas seleccionadas y las que no lo fueron.
#  - Eliminar los valores extremos que no sean relevantes para la predicción de valores de las propiedades.
#
# 2. Agregar información adicional respectiva al entorno de una propiedad a partir del [conjunto de datos de AirBnB](https://www.kaggle.com/tylerx/melbourne-airbnb-open-data?select=cleansed_listings_dec18.csv) utilizado en el práctico.
#   1. Seleccionar qué variables agregar y qué combinaciones aplicar a cada una. Por ejemplo, pueden utilizar solo la columna `price`, o aplicar múltiples transformaciones como la mediana o el mínimo.
#   1. Utilizar la variable zipcode para unir los conjuntos de datos. Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.
#   2. Investigar al menos otras 2 variables que puedan servir para combinar los datos, y justificar si serían adecuadas o no. Pueden asumir que cuentan con la ayuda de anotadores expertos para encontrar equivalencias entre barrios o direcciones, o que cuentan con algoritmos para encontrar las n ubicaciones más cercanas a una propiedad a partir de sus coordenadas geográficas. **NO** es necesario que realicen la implementación.
#
# Pueden leer otras columnas del conjunto de AirBnB además de las que están en `interesting_cols`, si les parecen relevantes.

# %% [markdown]
# #Ejercicio 2 punto 1
#
# Seleccionar un subconjunto de columnas que les parezcan relevantes al problema de predicción del valor de la propiedad. Justificar las columnas seleccionadas y las que no lo fueron.
#
#
# **Columnas relevantes** Estas se eligieron ya sea por que tengan algún grado relevante de correlación (las  numéricas) con el precio o con la ubicación o referencia del inmueble que permita referencialo en algún lugar especifico.
#
# **Melbourne**
#
# Suburb, Address, Rooms, Type,	Price,	Date,	Distance,	Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount
#
# **Airbnb**
#
# description, neighborhood_overview, street, neighborhood, city, suburb, state, zipcode, price, weekly_price, monthly_price, latitude, longitude,review_scores_rating
#
# **Columnas descartadas** El cambio de  estas variables no tiene vinculo o relación con el precio final del inmueble.
#
# **Melbourne**
#
# index, Method, SellerG

# %%
#171
# Justificamos la seleccion de celdas fijandonos en la correlacion con
# la variable Price

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15,15))
seaborn.set(font_scale=1)
sales_airbnb_join_df = pd.read_sql_query(sales_airbnb_join, engine)
# Generate a custom diverging colormap
cmap = seaborn.diverging_palette(240, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
seaborn.heatmap(sales_airbnb_join_df.corr(), cmap=cmap, center=0,
             square=True, linewidths=.5, annot=True)
# Out:
# 2022-06-07 21:19:09,031 INFO sqlalchemy.engine.Engine
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb GROUP BY int_zipcode)
#
#                   SELECT  m.*,
#                           avg_price,
#                           avg_monthly_price,
#                           avg_weekly_price,
#                           avg_review_scores_rating,
#                           zipcode_count
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
# 2022-06-07 21:19:09,034 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
#172
# El cambio de estas variables no tiene vinculo o relación con el precio final 
# del inmueble (por ello fueron descartadas).

f, ax = plt.subplots(figsize=(8,8))
x= sales_airbnb_join_df['index']
y = sales_airbnb_join_df['Price']
plt.scatter(x, y)

# %%
#173
# El cambio de estas variables no tiene vinculo o relación con el precio final 
# del inmueble (por ello fueron descartadas).

f, ax = plt.subplots(figsize=(8,8))
x = sales_airbnb_join_df['Method']
y = sales_airbnb_join_df['Price']
plt.scatter(x, y)

# %%
#174
# El cambio de estas variables no tiene vinculo o relación con el precio final 
# del inmueble (por ello fueron descartadas).

f, ax = plt.subplots(figsize=(28,8))
x= sales_airbnb_join_df['SellerG']
y = sales_airbnb_join_df['Price']
plt.scatter(x, y)

# %%
#180
#Eliminar los valores extremos que no sean relevantes para la predicción de valores de las propiedades.
PERCENTIL_MAXIMO = 0.95

price_avg= """
select Price from Melbourne
"""
price_avg_df = pd.read_sql_query(price_avg, engine).dropna()
price_limit = price_avg_df["Price"].quantile(PERCENTIL_MAXIMO)

#Eliminar los valores errones de código postal
# Out:
# 2022-06-07 21:48:14,212 INFO sqlalchemy.engine.Engine
# select Price from Melbourne
#
# 2022-06-07 21:48:14,215 INFO sqlalchemy.engine.Engine [raw sql] ()

# %% [markdown]
# #Respondemos a Ejercicio 2 Punto 2.1:
# Seleccionar qué variables agregar y qué combinaciones aplicar a cada una. Por ejemplo, pueden utilizar solo la columna price, o aplicar múltiples transformaciones como la mediana o el mínimo.

# %%
#181

# Segun Heatmap de celda 171, podemos ver la correlacion entre el Precio y
# Rooms (Melborune), Bedrom2 (Melbourne) y Bathroom (Merlbourne)
# Entonces podemos utilizar como predictor del Precio estas variables

"""
Join entre Melb y airbnb[interesting_cols] con filtros para cantidad de 
registros por zipcode (right) y límite de precios (left)
"""
filtered_join ="""
                  WITH airbnb_agg as 
                  (SELECT cast(zipcode as int) as int_zipcode, 
                          ROUND(AVG(weekly_price), 2) as avg_weekly_price,
                          COUNT(*) as zipcode_count
                  FROM Airbnb 
                  GROUP BY int_zipcode
                  HAVING zipcode_count > 4)

                  SELECT  int_zipcode,
                          m.Price, 
                          m.Rooms, 
                          m.Bedroom2,
                          m.Bathroom,
                          (m.Price/m.Rooms) as price_per_room,
                          (m.Price/m.Bedroom2) as price_per_bedroom,
                          (m.Price/Bathroom) as price_per_bathroom
                  FROM Melbourne m 
                  left join airbnb_agg a on m.Postcode == a.int_zipcode
                  WHERE m.Price < """ + str(price_limit)

df_price_predictor = pd.read_sql(filtered_join, engine)

#df.to_csv("melb_data_extended.csv", index=None)
#from google.colab import files
#files.download('melb_data_extended.csv')

df_price_predictor
# Out:
# 2022-06-07 22:25:47,522 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  int_zipcode,
#                           m.Price,
#                           m.Rooms,
#                           m.Bedroom2,
#                           m.Bathroom,
#                           (m.Price/m.Rooms) as price_per_room,
#                           (m.Price/m.Bedroom2) as price_per_bedroom,
#                           (m.Price/Bathroom) as price_per_bathroom
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999")
# 2022-06-07 22:25:47,532 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 22:25:47,536 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  int_zipcode,
#                           m.Price,
#                           m.Rooms,
#                           m.Bedroom2,
#                           m.Bathroom,
#                           (m.Price/m.Rooms) as price_per_room,
#                           (m.Price/m.Bedroom2) as price_per_bedroom,
#                           (m.Price/Bathroom) as price_per_bathroom
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999")
# 2022-06-07 22:25:47,539 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 22:25:47,542 INFO sqlalchemy.engine.Engine
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  int_zipcode,
#                           m.Price,
#                           m.Rooms,
#                           m.Bedroom2,
#                           m.Bathroom,
#                           (m.Price/m.Rooms) as price_per_room,
#                           (m.Price/m.Bedroom2) as price_per_bedroom,
#                           (m.Price/Bathroom) as price_per_bathroom
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999
# 2022-06-07 22:25:47,544 INFO sqlalchemy.engine.Engine [raw sql] ()
#        int_zipcode        Price  Rooms  Bedroom2  Bathroom  price_per_room  \
# 0         3,067.00 1,480,000.00      2      2.00      1.00      740,000.00
# 1         3,067.00 1,035,000.00      2      2.00      1.00      517,500.00
# 2         3,067.00 1,465,000.00      3      3.00      2.00      488,333.33
# 3         3,067.00   850,000.00      3      3.00      2.00      283,333.33
# 4         3,067.00 1,600,000.00      4      3.00      1.00      400,000.00
# ...            ...          ...    ...       ...       ...             ...
# 12896     3,049.00   582,000.00      3      3.00      2.00      194,000.00
# 12897     3,150.00 1,245,000.00      4      4.00      2.00      311,250.00
# 12898     3,016.00 1,031,000.00      3      3.00      2.00      343,666.67
# 12899     3,016.00 1,170,000.00      3      3.00      2.00      390,000.00
# 12900     3,013.00 1,285,000.00      4      4.00      1.00      321,250.00
#
#        price_per_bedroom  price_per_bathroom
# 0             740,000.00        1,480,000.00
# 1             517,500.00        1,035,000.00
# 2             488,333.33          732,500.00
# 3             283,333.33          425,000.00
# 4             533,333.33        1,600,000.00
# ...                  ...                 ...
# 12896         194,000.00          291,000.00
# 12897         311,250.00          622,500.00
# 12898         343,666.67          515,500.00
# 12899         390,000.00          585,000.00
# 12900         321,250.00        1,285,000.00
#
# [12901 rows x 8 columns]

# %% [markdown]
# #Ejercicio 2 punto 2
#
# Agregar información adicional respectiva al entorno de una propiedad a partir del conjunto de datos de AirBnB utilizado en el práctico.
#
# **2.B.**   Utilizar la variable zipcode para unir los conjuntos de datos. Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.

# %%
#190 Cantidad de filas por zipcode
pd.options.display.float_format = '{:.2f}'.format
print(price_avg_df["Price"].describe())
plt.figure(figsize=(12, 5))
plt.ticklabel_format(style='plain', axis='x')
seaborn.boxplot(price_avg_df["Price"])
# Out:
# count     13580.00
# mean    1075684.08
# std      639310.72
# min       85000.00
# 25%      650000.00
# 50%      903000.00
# 75%     1330000.00
# max     9000000.00
# Name: Price, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#200 Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.
zipcode_count ="""
select cast(zipcode as int) as zipcode, count(zipcode) as count 
  from Airbnb 
  group by zipcode
"""
  #having count(zipcode) < 1000
zipcode_count_df = pd.read_sql_query(zipcode_count, engine).dropna()
print(zipcode_count_df["count"].describe())

plt.figure(figsize=(12, 6))
seaborn.boxplot(zipcode_count_df["count"])
# Out:
# 2022-06-07 21:19:49,201 INFO sqlalchemy.engine.Engine
# select cast(zipcode as int) as zipcode, count(zipcode) as count
#   from Airbnb
#   group by zipcode
#
# 2022-06-07 21:19:49,203 INFO sqlalchemy.engine.Engine [raw sql] ()
# count    463.00
# mean      49.14
# std      147.48
# min        1.00
# 25%        5.00
# 50%       15.00
# 75%       40.00
# max     2491.00
# Name: count, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12, 6))
df_zipcode_filtrado = zipcode_count_df[(zipcode_count_df['count']> zipcode_count_df['count'].quantile(.25)) ]
#seaborn.lineplot(data=zipcode_count_df, x='zipcode', y='count')
seaborn.scatterplot(data=df_zipcode_filtrado, x='zipcode', y='count')

# %% [markdown]
# # Respondemos a Ejercicio 2 punto 2.2
# Utilizar la variable zipcode para unir los conjuntos de datos.
# Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.

# %%
#210
"""
Join entre Melb y airbnb[interesting_cols] con filtros para cantidad de 
registros por zipcode (right) y límite de precios (left)
"""
filtered_join ="""
                  WITH airbnb_agg as 
                  (SELECT cast(zipcode as int) as int_zipcode, 
                          ROUND(AVG(price), 2) as avg_price, 
                          ROUND(AVG(monthly_price), 2) as avg_monthly_price,
                          ROUND(AVG(weekly_price), 2) as avg_weekly_price,
                          ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
                          COUNT(*) as zipcode_count
                  FROM Airbnb 
                  GROUP BY int_zipcode
                  HAVING zipcode_count > 4)

                  SELECT  m.*, 
                          avg_price,
                          avg_monthly_price,
                          avg_weekly_price,
                          avg_review_scores_rating,
                          zipcode_count
                  FROM Melbourne m 
                  left join airbnb_agg a on m.Postcode == a.int_zipcode
                  WHERE m.Price < """ + str(price_limit)

df = pd.read_sql(filtered_join, engine)
df.to_csv("melb_data_extended.csv", index=None)
from google.colab import files
files.download('melb_data_extended.csv')
# Out:
# 2022-06-07 21:20:02,279 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  m.*,
#                           avg_price,
#                           avg_monthly_price,
#                           avg_weekly_price,
#                           avg_review_scores_rating,
#                           zipcode_count
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999")
# 2022-06-07 21:20:02,282 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 21:20:02,289 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  m.*,
#                           avg_price,
#                           avg_monthly_price,
#                           avg_weekly_price,
#                           avg_review_scores_rating,
#                           zipcode_count
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999")
# 2022-06-07 21:20:02,292 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-07 21:20:02,300 INFO sqlalchemy.engine.Engine
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  m.*,
#                           avg_price,
#                           avg_monthly_price,
#                           avg_weekly_price,
#                           avg_review_scores_rating,
#                           zipcode_count
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999
# 2022-06-07 21:20:02,302 INFO sqlalchemy.engine.Engine [raw sql] ()

# %%
plt.figure(figsize=(18, 9))
seaborn.heatmap(df.corr());

# %%
plt.figure(figsize=(18, 9))
yb = df[(df["avg_weekly_price"] > 1800) & (df["YearBuilt"] < 2022)]
df["avg_weekly_price_q"] = pd.qcut(df['avg_weekly_price'], 30,duplicates="drop")
#seaborn.barplot(data=df,x="avg_weekly_price_q",y="Price")
plt.ticklabel_format(style='plain', axis='y')
seaborn.barplot(data=df, x="Rooms", y="Price")
df[df["Rooms"]==8]
# Out:
#        index              Suburb           Address  Rooms Type      Price  \
# 1773    1926              Coburg      35 The Grove      8    u 2250000.00
# 3024    3255  Heidelberg Heights  478 Waterdale Rd      8    h  770000.00
# 3976    4285             Newport  487 Melbourne Rd      8    h  881000.00
# 5846    6201   Templestowe Lower    40 Ironbark Dr      8    h 1150000.00
# 7169    7581       Brighton East    22 Milliara Gr      8    h 1880000.00
# 10066  10611          Camberwell    1088 Toorak Rd      8    h 2200000.00
# 12570  13226      Meadow Heights      13 Haddon Ct      8    h  741000.00
#
#       Method SellerG        Date  Distance  ...  Lattitude  Longtitude  \
# 1773      PI   Peter   4/03/2017      7.80  ...     -37.75      144.97
# 3024      VB   Miles  19/11/2016     10.50  ...     -37.74      145.05
# 3976       S     Jas  30/07/2016      8.40  ...     -37.84      144.88
# 5846      PI   Barry   4/06/2016     13.80  ...     -37.77      145.12
# 7169      VB  Buxton  13/05/2017     10.70  ...     -37.91      145.02
# 10066     PI    Ross   8/07/2017      7.70  ...     -37.85      145.07
# 12570      S   Barry  23/09/2017     17.40  ...     -37.66      144.93
#
#                   Regionname  Propertycount  avg_price  avg_monthly_price  \
# 1773   Northern Metropolitan       11204.00     103.11            3624.17
# 3024    Eastern Metropolitan        2947.00      83.66             937.50
# 3976    Western Metropolitan        5498.00     132.05            2002.33
# 5846    Eastern Metropolitan        5420.00     228.26            1400.00
# 7169   Southern Metropolitan        6938.00     193.87            1116.00
# 10066  Southern Metropolitan        8920.00     138.56            2742.57
# 12570  Northern Metropolitan        4704.00        NaN                NaN
#
#        avg_weekly_price avg_review_scores_rating  zipcode_count  \
# 1773             896.06                    94.88         133.00
# 3024             291.43                    94.00          38.00
# 3976             706.12                    95.29          65.00
# 5846             350.00                    90.31          19.00
# 7169             376.88                    93.35          53.00
# 10066            526.67                    96.17          88.00
# 12570               NaN                      NaN            NaN
#
#        avg_weekly_price_q
# 1773     (868.15, 920.08]
# 3024      (197.5, 306.67]
# 3976     (658.33, 706.12]
# 5846      (306.67, 351.0]
# 7169      (351.0, 379.31]
# 10066    (525.43, 553.15]
# 12570                 NaN
#
# [7 rows x 28 columns]

# %% [markdown]
# #Ejercicio 2 punto 3
#
# Investigar al menos otras 2 variables que puedan servir para combinar los datos, y justificar si serían adecuadas o no. Pueden asumir que cuentan con la ayuda de anotadores expertos para encontrar equivalencias entre barrios o direcciones, o que cuentan con algoritmos para encontrar las n ubicaciones más cercanas a una propiedad a partir de sus coordenadas geográficas. NO es necesario que realicen la implementación.

# %% [markdown]
# 220
#
# Una opción podría ser combinar cada registro con el agrupado de las n ubicaciones más cercanas teniendo en cuenta las columnas de latitud/longitud presentes en ambos datasets, tomando los valores medios de cada grupo para asociar a cada fila.
#
# Otra opción sería tomar la dirección y asociarla a su equivalencia en el otro dataset, pero en este caso el dato de la dirección sólo está presente en el dataset de Melbourne, en cambio en el de Airbnb sólo hay una columna "street", que contiene un dato casi equivalente a "Suburb", por ende no nos sirve para encontrar la equivalencia.

# %%
#230

# columna de dirección en dataset de Melbourne
query ="""
select Address  
  from Melbourne m 
"""
join = pd.read_sql_query(query, engine)
print(join.head())
# Out:
# 2022-06-07 21:23:31,210 INFO sqlalchemy.engine.Engine
# select Address
#   from Melbourne m
#
# 2022-06-07 21:23:31,212 INFO sqlalchemy.engine.Engine [raw sql] ()
#             Address
# 0      85 Turner St
# 1   25 Bloomburg St
# 2      5 Charles St
# 3  40 Federation La
# 4       55a Park St

# %%
#240

# columna de calle en dataset de Airbnb
query ="""
select street, suburb   
  from Airbnb a
"""
join = pd.read_sql_query(query, engine)
print(join.head())
# Out:
# 2022-06-07 21:23:45,253 INFO sqlalchemy.engine.Engine
# select street, suburb
#   from Airbnb a
#
# 2022-06-07 21:23:45,257 INFO sqlalchemy.engine.Engine [raw sql] ()
#                            street          suburb
# 0         Bulleen, VIC, Australia         Bulleen
# 1  Brunswick East, VIC, Australia  Brunswick East
# 2        St Kilda, VIC, Australia        St Kilda
# 3       Thornbury, VIC, Australia       Thornbury
# 4   St Kilda East, VIC, Australia   St Kilda East

# %% [markdown]
# ## Ejercicio 3:
#
# Crear y guardar un nuevo conjunto de datos con todas las transformaciones realizadas anteriormente.

# %%
#W--------------------------------------------------

df = pd.read_sql(filtered_join, engine)
df.to_csv("melb_data_extended.csv", index=None)
from google.colab import files
files.download('melb_data_extended.csv')
# Out:
# 2022-06-02 00:54:22,435 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  m.*,
#                           avg_price,
#                           avg_monthly_price,
#                           avg_weekly_price,
#                           avg_review_scores_rating,
#                           zipcode_count
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999")
# 2022-06-02 00:54:22,439 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-02 00:54:22,444 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  m.*,
#                           avg_price,
#                           avg_monthly_price,
#                           avg_weekly_price,
#                           avg_review_scores_rating,
#                           zipcode_count
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999")
# 2022-06-02 00:54:22,446 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-02 00:54:22,449 INFO sqlalchemy.engine.Engine
#                   WITH airbnb_agg as
#                   (SELECT cast(zipcode as int) as int_zipcode,
#                           ROUND(AVG(price), 2) as avg_price,
#                           ROUND(AVG(monthly_price), 2) as avg_monthly_price,
#                           ROUND(AVG(weekly_price), 2) as avg_weekly_price,
#                           ROUND(AVG(review_scores_rating), 2) as avg_review_scores_rating,
#                           COUNT(*) as zipcode_count
#                   FROM Airbnb
#                   GROUP BY int_zipcode
#                   HAVING zipcode_count > 4)
#
#                   SELECT  m.*,
#                           avg_price,
#                           avg_monthly_price,
#                           avg_weekly_price,
#                           avg_review_scores_rating,
#                           zipcode_count
#                   FROM Melbourne m
#                   left join airbnb_agg a on m.Postcode == a.int_zipcode
#                   WHERE m.Price < 2290049.999999999
# 2022-06-02 00:54:22,451 INFO sqlalchemy.engine.Engine [raw sql] ()

# %% [markdown]
# ## Ejercicios opcionales:
#
# 1. Armar un script en python (archivo .py) [ETL](https://towardsdatascience.com/what-to-log-from-python-etl-pipelines-9e0cfe29950e) que corra los pasos de extraccion, transformacion y carga, armando una funcion para cada etapa del proceso y luego un main que corra todos los pasos requeridos.
#
# 2. Armar un DAG en Apache Airflow que corra el ETL. (https://airflow.apache.org/docs/apache-airflow/stable/tutorial.html)
